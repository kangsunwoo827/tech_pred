# %%
import pandas as pd

df = pd.read_excel('Top_oil_companies.xlsx')
df.dropna(subset=['출원인'], inplace=True)
df['출원인'] = df['출원인'].str.lower()

# %%
sum(df['출원인']. apply(lambda x: '|' in x)) / len(df['출원인'])
# Out:
# 0.20476405169822662

# %%
df['companies'] = df['출원인'].apply(lambda x: '|'.join(sorted(set(x.split('|')))))
for i,value in enumerate(df['companies'].str.split('|', expand=True).iloc[:,6]):
    if value:
        print(i)
# Out:
# 1182
# 1188

# %%
df['companies'].iloc[1182]
# Out:
# 'basell polyolefine gmbh|basf antwerpen n.v.|borealis a.g.|bp europa se|chemelot campus b.v.|sabic global technologies b.v.|total research and technology feluy'

# %%
df.columns
# Out:
# Index(['일련번호', '번호', '명칭', '요약', '출원인', '출원인국가', '출원인대표명', '발명자', '발명자국가',
#        '국제특허분류', '공통특허분류', '미국특허분류', '출원번호', '출원일', '공개번호', '공개일', '공고번호',
#        '공고일', '등록번호', '등록일', '우선권번호', '국제출원번호', '국제출원일', '국제공개번호', '국제공개일',
#        'INPADOC 패밀리', 'Simple 패밀리', '심사관', '대리인', '지정국가', '독립 청구항수', '전체 청구항수',
#        '대표 청구항', '대표 청구항(원문)', '권리 현황', '최종 상태', '현재소유자', '권리만료예상일', '자국인용특허',
#        '외국인용특허', '자국피인용특허', '자국인용횟수', '자국피인용횟수', '특허평가등급', '특허평가점수',
#        '발명자평가평균등급', '발명자평가평균점수', 'FI', 'F-Term', 'INPADOC패밀리수',
#        'INPADOC패밀리국가수', 'Simple패밀리수', 'Simple패밀리국가수', '발명자수', 'Genealogy수',
#        '패밀리 번호', '전용실시권자', '통상실시권자', 'INPADOC패밀리국가', 'Simple패밀리국가', '소유권이전여부',
#        '소유권최종양도일', '특허전문 Link', 'companies'],
#       dtype='object')

# %%
# 회사명 통일성 확보
df['companies'] = df['출원인'].apply(lambda x: list(sorted(set(x.split('|')))))

# Create separate rows for each combination
df_expanded = df.explode('companies')
# 결과 출력
print(df_expanded['companies'].value_counts()[:30])
# Out:
# companies
# saudi arabian oil company                                                                  4694
# shell oil company                                                                          1870
# chevron u.s.a. inc.                                                                        1496
# sk innovation co., ltd.                                                                     975
# china petroleum & chemical corporation                                                      707
# shell internationale research maatschappij b.v.                                             414
# chevron phillips chemical company lp                                                        380
# eni s.p.a.                                                                                  338
# bp corporation north america inc.                                                           323
# total sa                                                                                    320
# petrochina company limited                                                                  270
# equinor energy as                                                                           224
# petróleo brasileiro s.a. - petrobras                                                        223
# chevron oronite company llc                                                                 164
# research institute of petroleum processing, sinopec                                         142
# beijing research institute of chemical industry, china petroleum & chemical corporation     112
# sk ie technology co., ltd.                                                                  111
# sk global chemical co., ltd.                                                                 96
# bp exploration operating company limited                                                     93
# suncor energy inc.                                                                           80
# king abdullah university of science and technology                                           75
# shanghai research institute of petrochemical technology, sinopec                             75
# sk on co., ltd.                                                                              74
# aramco services company                                                                      73
# bp p.l.c.                                                                                    72
# sk innovation co.,ltd.                                                                       64
# shell usa, inc.                                                                              56
# king fahd university of petroleum & minerals                                                 53
# petroleo brasileiro s.a. - petrobras                                                         45
# sk geo centric co., ltd.                                                                     44
# Name: count, dtype: int64

# %%
name_first_words=set()
for name in df_expanded['companies'].value_counts().index:
    name_first_words.add(name.replace('-',' ').split()[0])
print(name_first_words)
# Out:
# {'field', 'electricite', 'exxon', 'universidade', 'shanxi', 'petroled', 'jindal', '.', 'texa', 'trelleborg', 'lawrence', 'centre', 'three', 'hyundai', 'exxonmobile', 'cameron', 'serviço', 'berndorf', 'daqing', 'imec', 'cggveritas', 'turner,', 'cnrs', 'petrobras', '3x', 'basell', 'statoil', 'services', 'rutgers,', 'sk', 'mitsubishi', 'hydrus', 'kemira', 'totalenergies', 'jgc', 'brown', 'arteco', 'fca', 'silixa', 'shanghai', 'eif—astute', 'exxonmobil', 'schlumber', 'verdun;', 'piacsek', 'sdg', 'rocketheart', 'clariant', 'trustees', 'landmark', 'association', 'armines', 'avitas', 'polymeright,', 'unist', 'truva', 'fonds', 'ipt', 'blackpoint', 'ecole', 'japan', 'beiging', 'consejo', 'bgp', 'suez', 'petroleum', 'chervon', 'johnson', 'fuel', 'petrochina', 'physeis', 'alfaisal', 'bluebridge', 'ucl', 'schlumberger', 'hibot', 'ste', 'ineos', 'william', 'equinor', 'reveal', 'silgan', 'delp', 'wonderland', 'regents', 'butamax', 'technip', "l'air", 'tenet', 'suncar', 'select', 'king', 'petroleo', 'universite', 'meg', 'shanks', 'saud', 'xiamen', 'georgia', 'weatherford', 'apix', 'consiglio', 'cnpc', 'suncore', 'central', 'servico', 'yu', 'electricité', 'bp', 'union', 'cvs', 'opterra', 'airguard', 'basf', 'amply', 'cumulus', 'chevron', 'kellogg', 'universitat', 'codexis,', 'nov', 'jiangsu', 'petròleo', 'covar', 'shell', 'danish', 'novozymes', 'environmental', 'marathon', 'sichuan', 'obschestvo', 'international', 'pontificia', 'seoul', 'kangnam', 'eca', 'varel', 'membrain', 'electro', 'enui', 'nexflex', 'asudi', 'rybkarock', 'northwest', 'vws', 'syngenta', 'shengli', 'saipem', 'université', 'industry', 'c̆eské', 'san', 'university', 'veolia', 'los', 'breda', 'total', 'snu', 'bolecon', 'chevon', 'cantech', 'petro', 'wild', 'roberts,', 'senseor', 'fundacao', 'zurich', 'obshchestvo', 'baker', 'dailan', 'uop', 'popeszku;', 'rosneft', 'pb', 'the', 'ifp', 'biosynthetic', 'nke', 'quantumcorrugated', 'centro', 'eni', 'vadovations,', 'suadi', 'tsinghua', 'green', 'applied', 'china', 'marquette', 'institute', 'building', 'research', 'gas', 'twi', 'samsung', 'sasol', 'changqing', 'ceramatec,', 'solid', 'yangtze', 'american', 'colorado', 'cranfield', 'zhejiang', 'nippon', 'm', 'massachusetts', 'intertape', 'carnegie', 'cnr', 'petrobrás', 'salamander', 'national', 'schlumbeger', 'daelim', 'sinpopec', 'bambino', 'lummus', 'arkema', 'macquarie', 'lanzhou', 'triad', 'saidi', 'novvi', 'industrial', 'root,', 'união', 'petrochemical', 'hunan', 'novosibirsk', 'petroleao', 'polimeri', 'int—instituto', 'heavy', 'prosternat', 'membrane', 'endserv', 'metarock', 'b.p.', 'sabic', 'drillscan', 'rs', 'raytheon', 'sinopec', 'integrity', 'sa', 'gm', 'chevorn', 'sun', 'boreskov', 'california', 'air', 'oil', 'bacchin;', 'cornell', 'lytt', 'seriço', 'texas', 'honeybee', 'trofimuk', 'solvay', 'durahm', 'chengdu', 'lukoil', 'chemelot', 'geoservices', 'foro', 'commonwealth', 'synhelion', 'instituto', 'akzo', 'geosteering', 'mega', 'drexel', 'axens', 'kuwait', 'bioecon', 'bandpay', 'cidra', 'siemens', 'mason;', 'groundmetrics,', 'riber', 'techlam', 'board', 'suncor', 'electronics', 'heriot', 'soletanche', 'kasab', 'steam', 'sumitomo', 'hjelmco', 'petróleo', 'institut', 'arizona', 'tea', 'borealis', 'cnpem', 'sicat', 'overpipe', 'arcadis', 'c/o', 'openfield', 'luoyang', 'halliburton', 'fushun', 'beijing', 'uchicago', 'versalis', 'odotech', 'jme', 'misuzu', 'sheell', 'saudi', 'trendsetter', 'eth', 'durham', 'nanjing', 'saudia', 'bashkir', 'aramco', 'eni,', 'chrysaor', 'general', 'univerisdade', 'gopro,', 'kms', 'faculdades', 'office', 'z', 'doris', 'posco', 'virent,', 'schlumbergr', 'drilling', 'sdg,', 'fundação', 'flying', 'skgc', 'schulmberger', 'emery', 'ohio', 'dalian', 'korea', 'southwest', 'wireless', 'prosernat', 'yunsung', 'interwell', 'zennor', 'thermo', 'bpm', 'zhong', 'commissariat'}

# %%
top_IOaGI_30 = [
'Saudi Arabian Oil Co',
'Petróleo Brasileiro SA - Petrobras',
'PJSC LUKOIL',
'Exxon Mobil Corp',
'Public JSC Gazprom',
'TotalEnergies SE',
'Equinor ASA',
'Chevron Corp',
'Shell plc',
'China Petroleum & Chemical Corp',
'Oil & Natural Gas Corp Ltd',
'Surgutneftegas Public JSC',
'PetroChina Co Ltd',
'Eni S.p.A.',
'BP p.l.c.',
'Suncor Energy Inc',
]

top_IOaGI_30 = [i.lower() for i in top_IOaGI_30]
top_IOaGI_30
# Out:
# ['saudi arabian oil co',
#  'petróleo brasileiro sa - petrobras',
#  'pjsc lukoil',
#  'exxon mobil corp',
#  'public jsc gazprom',
#  'totalenergies se',
#  'equinor asa',
#  'chevron corp',
#  'shell plc',
#  'china petroleum & chemical corp',
#  'oil & natural gas corp ltd',
#  'surgutneftegas public jsc',
#  'petrochina co ltd',
#  'eni s.p.a.',
#  'bp p.l.c.',
#  'suncor energy inc']

# %%
top2comp={name:[] for name in top_IOaGI_30}
top2comp['sk innovation']=[]

# %%
len(top_IOaGI_30)
# Out:
# 16

# %%
len(df)
# Out:
# 13308

# %%
len(df_expanded)
# Out:
# 16273

# %%
pass_num = 0
cannot_classify_num =0
for company in df_expanded['companies'].value_counts().index:
    if 'institute' in company or 'university' in company or 'universite' in company:
        pass_num+=1
        continue
    isin= False
    
    if 'lukoil' in company:
        top2comp['pjsc lukoil'].append(company)
        isin =True
    elif 'sk' in company:
        top2comp['sk innovation'].append(company)
        isin = True
    elif 'petroleo' in company:
        top2comp['petróleo brasileiro sa - petrobras'].append(company)
        isin = True
        
    for name in top2comp:
        if name.split()[0] in company:
            top2comp[name].append(company)
            isin = True
            
    
    
    if not isin:
        cannot_classify_num+=1
        print(company)
        
print(pass_num)   
print(cannot_classify_num)
# Out:
# total sa
# aramco services company
# schlumberger technology corporation
# ifp energies nouvelles
# halliburton energy services, inc.
# uop llc
# universidade federal do rio de janeiro - ufrj
# jgc catalysts and chemicals ltd.
# triad national security, llc
# aramco far east (beijing) business services co., ltd.
# centre national de la recherche scientifique
# japan cooperation center petroleum
# aramco innovations llc
# sabic global technologies b.v.
# versalis s.p.a.
# georgia tech research corporation
# wireless instrumentation systems as
# universidade federal do rio grande do sul - ufrgs
# ecole polytechnique
# cameron international corporation
# silixa ltd.
# vadovations, inc.
# consiglio nazionale delle ricerche
# biosynthetic technologies, llc
# aramco overseas company uk ltd
# shanxi lu'an environmental energy development co. ltd.
# total se
# sdg llc
# universidade federal de minas gerais
# japan cooperation center, petroleum
# m-i drilling fluids uk ltd
# sinopec tech houston, llc.
# air products and chemicals, inc.
# shanghai bi ke clean energy technology co., ltd.
# ineos us chemicals company
# meg energy corp.
# sinopec engineering incorporation
# intertape polymer corp.
# los alamos national security, llc
# bioecon international holding n.v.
# aramco overseas company b.v.
# sinopec shengli petroleum engineering co., ltd
# johnson matthey davy technologies limited
# ceramatec, inc.
# universidade federal de minas gerais - ufmg
# opterra energy services, inc.
# los alamos national security llc
# biosynthetic technologies, llc.
# sinopec qilu company
# lytt limited
# groundmetrics, inc.
# siemens energy, inc.
# centre national de la recherche scientifique (cnrs)
# sinopec yangzi petrochemical co., ltd.
# schlumberger technology b.v.
# saipem s.a.
# universitat politecnica de valencia
# synhelion sa
# international business machines corporation
# openfield technology
# fca fiat chrysler automoveis brasil ltda
# consejo superior de investigaciones cientificas
# unist academy-industry research corporation
# universidade federal de santa catarina - ufsc
# ineos acetyls uk limited
# sumitomo chemical company, limited
# universidade federal do rio grande - furg
# electricite de france
# sinopec petroleum engineering technology service co., ltd.
# sinopec catalyst co., ltd.
# fundacao de amparo a pesquisa do estado de minas gerais - fapemig
# sinopec jinling petrochemical co., ltd.
# japan cooperation center for petroleum and sustainable energy
# universidade federal de santa maria - ufsm
# honeybee robotics, ltd.
# jgc catalysts & chemicals ltd.
# chengdu dongwei technology co., ltd
# technip e&c limited
# universidade federal do rio de janeiro
# universidade federal do espírito santo - ufes
# arteco nv
# 3x engineering
# sinopec petroleum engineering technology service co., ltd
# hunan changling petrochemical science and technology development co., ltd
# prosernat
# universidade estadual de campinas - unicamp
# instituto nacional de tecnologia - int
# cggveritas services s.a.
# flying whales
# blackpoint tactical llc
# l'air liquide societe anonyme pour l'etude et l'exploitation des procedes georges claude
# institut photovoltaïque d'ile de france (ipvf)
# weatherford international, llc
# hunan changling petrochemical science and technology development co., ltd.
# apix analytics
# field upgrading usa, inc.
# novvi llc
# total france
# petrobras
# universidade federal do rio de janeiro-ufrj
# cnrs (centre national de la recherche scientifique)
# centre national de la recherche scientifique—cnrs
# axens
# membrane technology and research, inc.
# wild well control, inc.
# total marketing services
# truva corporation
# hibot corporation
# general electric company
# airguard ltd.
# chervon oronite company llc
# reveal energy services, inc.
# riber
# universidade federal do rio grande do sul—ufrgs
# centre national de la recherche scientifique - cnrs -
# ineos styrolution group gmbh
# mitsubishi chemical holdings corp
# silixa limited
# electricité de france
# institut photovoltaique d'ile de france
# cidra corporate services inc.
# serviço nacional de aprendizagem industrial departamento regional de santa catarina - senai/sc
# sinopec chongqing svw chemical co., ltd.
# universidade federal fluminense - uff
# twi ltd.
# total research and technology feluy
# services petroliers schlumberger
# chemelot campus b.v.
# borealis a.g.
# basf antwerpen n.v.
# basell polyolefine gmbh
# schlumberger canada limited
# instituto tecnológico de aeronáutica - ita
# sinopec tech houston
# membrane technology and research, inc
# faculdades catolicas
# sinopec zhongyuan petroleum engineering co., ltd
# schlumberger middle east, s.a.
# aramco far east (beijing) business service co. ltd.
# overpipe sas
# trelleborg offshore uk ltd
# universidade federal de uberlândia - ufu
# services pétroliers schlumberger
# rs auto co., ltd.
# cnpc engineering technology r&d company limited
# amply power, inc.
# chrysaor petroleum company u.k. limited
# nke instrumentation
# trendsetter vulcan offshore, inc.
# cnpem - centro nacional de pesquisa em energia e materiais
# armines
# institut de la corrosion
# universidade de são paulo - usp
# eca
# sinopec yangzi petrochemical company ltd.
# geoservices equipements
# fonds de l'espci- georges charpak
# aramco overseas company uk ltd.
# covar applied technologies, inc.
# ecole nationale supérieure des sciences agronomique de bordeaux-aquitaine
# drillscan
# instituto de pesquisas tecnologicas do estado de sao paulo s.a. - ipt
# varel europe
# novozymes a/s
# chrysaor (u.k.) theta limited
# los alamos national laboratory
# chrysaor production (u.k.) limited
# zennor resources (n.i.) limited
# research instittute of petroleum processing, sinopec
# kasab international energy services co. ltd.
# solvay specialty polymers usa, llc.
# schlumberger holdings limited
# cggveritas services sa
# fushun research inst of petroleum & petrochemicals sinopec corp
# clariant s.a.
# verdun; harris joseph
# root, jr.; david emerson
# butamax advanced biofuels llc
# popeszku; laszlo emil
# instituto de tecnologia para o desenvolvimento-lactec
# los alamos national security, llc.
# schulmberger technology corporation
# kellogg brown & root llc
# universidade estadual de campinas
# arcadis corporate services, inc.
# centro tecnológico do exército - exército brasileiro
# universidade federal do rio grande do norte - ufrn
# applied research associates, inc.
# odotech inc.
# nexflex co., ltd.
# .
# total reserche & development sas
# association pour la recherche et le developpement des methodes et processus industriels
# salamander solutions, llc
# petròleo brasileiro s.a. -petrobras
# sichuan kcon valve mfg co., ltd.
# physeis consultant
# universidade federal de uberlândia-ufu
# faculdades católicas
# pontificia universidade católica do rio de janeiro - puc-rio
# universidade de sao paulo-usp
# université d'aix-marseille
# veolia eau—compagnie generale des eaux
# vws westgarth ltd.
# snu r&db foundation
# cantech industries, llc
# solid carbon products, llc
# universidade federal do rio de janeiro—ufrj
# jme limited
# select energy systems inc.
# bacchin; paolo
# texa s.p.a.
# fundação universidade federal de são carlos
# sinopec tech houston, llc
# eif—astute
# tea sistemi s.p.a.
# universidade federal de viçosa - ufv
# colorado school of mines
# gm flow measurement services ltd.
# imec
# shanks tech ltd
# centre national de la recherche scientifique- cnrs
# wild well control inc.
# silgan holdings, inc.
# hydrus corporation, inc.
# ste des fibres de carbone
# jindal films americas llc
# polimeri europa s.p.a.
# hunan changling petrochemical science and technology development co. ltd.
# soletanche freyssinet
# uchicago argonne, llc
# chevon oronite technology b.v.
# doris engineering
# codexis, inc.
# trofimuk lnstitute of petroleum geology and geophysics
# bolecon international holding n.v.
# halliburton energy services, inc
# turner, craig, robert
# sabic global technology b.v.
# jgc catalysts and chemical ltd.
# mason; clint
# metarock laboratories
# rybkarock
# chevorn u.s.a. inc.
# sa texaco belgium nv
# sasol technology (pty) ltd
# eth zurich
# universidade federal do rio grande do sul-ufrgs
# commonwealth scientific and industrial research organisation
# aramco service comapny
# polymeright, inc.
# int—instituto nacional de tecnologia
# instituto nacional de tecnologia-int
# los alamos national security
# intertape polymer corporation
# virent, inc.
# roberts, mark peter
# centre national de la recherche scientifique (c.n.r.s.)
# chengdu dongwei technology co., ltd.
# berndorf band gmbh
# sinopec matrix corporation
# changqing engineering design co., ltd.
# seriço nacional de aprendizagem industrial departamento regional de santa catarina - senai/sc
# fuel guard systems corporation
# sicat llc
# regents of the univ of california san diego:the
# b.p. children's products hk co. limited
# luoyang petrochemical engineering corporation/sinopec
# wonderland nurserygoods company limited
# american chemical technologies, inc.
# foro energy, inc.
# université de pau et des pays de l'adour
# obshchestvo s ogranichennoy otvestvennostyu "promyshlennyye vodorodnyye tekhnologii inzhenering"
# lawrence livermore national laboratory
# lawrence livermore national security, llc
# landmark graphics corporation
# daelim industrial co., ltd.
# hyundai engineering co. ltd.
# korea gas corporation
# emery oleochemicals gmbh
# universidade federal da bahia - ufba
# universidade estadual paulista "julio de mesquita filho" - unesp
# l'air liquide, societe anonyme pour l'etude et l'exploitation des procedes georges claude
# avitas systems, inc.
# m-i drilling fluids uk limited
# universidade federal de goias – ufg
# universidade federal de minas gerais-ufmg
# ecole normale superieure de lyon
# arkema france
# industrial and mechanical services co. ltd
# kemira oyj
# instituto de tecnologia para o desenvolvimento—lactec
# centre national de la recherche scientifique-cnrs-
# serviço nacional de aprendizagem industrial - departamento regional do rio grande do sul
# breda energia s.p.a.
# veolia eau-compagnie generale des eaux
# vws westgarth ltd
# integrity insitu
# universidade federal do espirito santo-ufes
# petrobrás transportes s/a. - transpetro
# bandpay & greuter
# commissariat a l'énergie atomique et aux energies alternatives
# enui s.p.a.
# aramco far east (beijing) business service co. ltd (abs)
# mega a.s.
# membrain s.r.o.
# instituto de tecnologia quimica, upv-csic
# hjelmco ab
# c/o instituto de technologia quimica, upv-csic
# association scientifique pour la géologie et ses applications
# ipt- instituto de pesquisas tecnologicas do estado de sao paulo s/a
# centre national de la recherche scientifque—cnrs
# serviço nacional de aprendizagem industrial,departamento regional da bahia - senai/dr/ba
# universidade federal de minas gerais—ufmg
# techlam
# office national d'etudes et de recherches aérospatiales
# bluebridge technologies ltd.
# pb solutions, llc
# the administrators of the tulane educational fund
# cornell center for technology, enterprise & commercialization
# serviço nacional de aprendizagem industrial, departamento regional da bahia – senai/dr/ba
# serviço nacional de aprendizagem industrial - departamento regional da bahia-senai/dr/ba
# universidade federal de minas gerais – ufmg
# endserv inspecão de equipamentos e materiais ltda me
# sdg, llc
# drilling engineering technology research inst. of sinopec zhongyuan petroleum engineering co., ltd
# universidade federal do rio de janeiro -ufrj
# beijing sanju environmental protection & new materials co., ltd.
# univerisdade federal do estado do rio de janeiro - ufrj
# universidade federal de pernambuco -ufpe
# universidade federal de itajubá - unifei
# fundação universidade federal de são carlos - ufscar
# universidade federal de goiás - ufg
# serviço nacional de aprendizagem industrial – senai - dr/rn
# akzo nobel chemicals international b.v.
# electro-flow controls ltd
# universidade tecnologica federal do parana
# clariant international ltd
# petroleao brasileiro s.a. - petrobas
# servico nacional de aprendizagem industrial-departamento regional de santa catarina-senai/sc
# universidade federal do ceara—ufc
# green imaging technologies, inc.
# ucl business plc
# interwell norway as
# universidade federal de viçosa
# membrane technology and research
# jiangsu suyan jingshen co., ltd.
# central national de la recherche scientifique
# yu technologies, inc.
# sun-central (shanghai) marketing and service co., ltd
# servico nacional de aprendizagem industrial—departamento regional de santa catarina
# fundacao de amparo a pesquisa do estado de minas gerais- fapemig
# silixa ltd
# quantumcorrugated s.r.l.
# petroled brasilelro s.a. - petrobras
# thermo fisher scientific (bremen) gmbh
# servico nacional de aprendizagem industrial—departmento regional de santa catarina
# three cliffs geomechanical analysis limited
# servico nacional de aprendizagem industrial - departamento regional de santa catarina
# the cleveland clinic foundation
# schlumber technology corporation
# delp engenharia mecânica s/a
# basf se
# syngenta participations ag
# bambino prezioso switzerland ag
# schlumbeger technology corporation
# universidade federal do parana
# aramco sevices company
# gas capture technologies
# bgp arabia co. ltd.
# posco
# beijing orienda instruments co., ltd.
# schlumbergr technology corporation
# m-i drilling fluids u.k. limited
# cvs ferrari s.p.a.
# união brasileira de educagao e assistencia—mantenedora da pucrs
# king abdulaziz city for science and technology
# rocketheart technology co. ltd
# raytheon company
# yunsung f&c co., ltd
# universidade de sao paulo—usp
# basf corporation
# salamander soultions inc.
# air liquide advanced technolgies u.s. llc
# jgc catalysts & chemicals ltd
# l'air liquide societe anonyme pour l'etude et l'etude et l'exploitation des procedes georges claude
# cnr international
# air liquide advanced technologies u.s. llc
# serviço nacional de aprendizagem industrial departamento regional de santa ca
# the shepherd chemical company
# instituto nacional de tecnologia—int
# ecole nationale superieure de chimie de montpellier
# total s.a.
# piacsek borges, crístiano
# suez international
# gopro, inc.
# jgc catalyst and chemicals ltd.
# ohio state innovation foundation
# servico nacional de aprendizagem industrial - departamento regional de santa catrina sanai/sc
# universidade federal da bahia
# prosternat
# tenet s.r.l.
# suncar energy inc.
# sabic global technologies, b.v.
# jgc catalyst and chemicals, ltd.
# ecole nationale supérieure de chimie de montpelli
# the lubrizol corporation
# zhong shi da engineering research center co. ltd.
# veolia water solutions technologies support
# cidra corporate services llc
# universidade federal do rio grande do norte
# environmental refuelling systems inc.
# universidade federal fluminense—uff
# ecole nationale supérieure de chimie de montpellier
# baker hughes incorporated
# senseor
# air liquide advanced technologies u.s., llc
# halliburton energy services inc.
# cumulus digital systems, inc.
# prosernat sa
# lummus technology llc
# serviço nacional de aprendizagem industrial - senai
# baker hughes, a ge company, llc
# kangnam jevisco co ltd
# institut photovoltaique d'ile de france - ipvf
# nov subsea products as
# beijing sino-hypro petrochemical tech. co.ltd.
# z terra inc.
# 199
# 428

# %%
n = 0
my_list=[]
for key in top2comp:
    n+=len(top2comp[key])
    top2comp[key]=list(set(top2comp[key]))
    my_list.extend(top2comp[key])
    
print(len(set(my_list)))
n

duplicates = set()
unique_values = set()

for value in my_list:
    if value in unique_values:
        duplicates.add(value)
    else:
        unique_values.add(value)

print("중복된 값:", list(duplicates))
# Out:
# 295
# 중복된 값: ['obschestvo s ogranichennoi otvestvennostyu "lukoil-nizhegorodsky nauchno-issledovatelskii i proektnii institut po pereraboteke nefti"', 'shell oil comapny', 'saudi arabian oil componv', 'saudi arabian oil company and', 'exxonmobil oil corporation', 'saudi arabia oil company', 'saudi arabian oil comoanv', 'obschestvo s ogranichennoi otvetstvennostyu "lukoil - nizhegorodsky nauchno-issledovatelsky i proektny institut po pererabotke nefti"', 'bp (china) holdings ltd', 'petrochina huabei oilfield company', 'shell oil ocmpany', 'lukoil marine lubricants germany gmbh', 'saudi arabian oil company, dhahran, saudi arabia', 'bp oil international limited', 'saudi arabian oil companyd', 'saudi  arabian oil company', 'petrochina company limited', 'saudi arabian oil company', 'saudi arabian oil comoany', 'petrochina company ltd.', 'saudia arabian oil company', 'shell oil compnay', 'saudi arabian oil compnay', 'shell oil cpmpany', 'bp (china) holdings limited', 'saudi arbian oil company', 'saudi arabian oil compay', 'petrochina west pipeline company', 'northwest oilfield branch, china petroleum & chemical co., ltd.', 'china petroleum & chemical corporation southwest oil & gas company', 'chevron (china) chemicals co., ltd.', 'saudi arabian oil comapny', 'saudi arabian oil co', 'saudi arabian oil conpany', 'shengli oilfield branch, china petroleum & chemical co., ltd', 'shell oil co,pany', 'shell oil company', 'bp (china) holdings co., ltd.', 'northwest oilfield branch, china petroleum & chemical co., ltd']

# %%
duplicate_comp = list(duplicates)[0]
print (duplicate_comp)
for key in top2comp:
    if duplicate_comp in top2comp[key]:
        print(key)
# Out:
# obschestvo s ogranichennoi otvestvennostyu "lukoil-nizhegorodsky nauchno-issledovatelskii i proektnii institut po pereraboteke nefti"
# pjsc lukoil
# oil & natural gas corp ltd
# sk innovation

# %%
df[~df['공개일'].isna()]
# Out:
#         일련번호              번호  \
# 0          1    WO23196956A1
# 1          2    WO23196806A1
# 2          3    WO23196613A1
# 3          4    WO23195875A1
# 4          5    WO23195710A1
# ...      ...             ...
# 13092  13097       US8697599
# 13093  13098       US8461404
# 13094  13099  JP2011105771A2
# 13095  13100  JP2011099122A2
# 13096  13101       US8246812
#
#                                                       명칭  \
# 0                 FOAM STABILIZATION USING NANOPARTICLES
# 1      CHROMIUM-CATALYZED REACTIONS OF CARBON MONOXID...
# 2      METHOD FOR CO2 SEQUESTRATION MEASUREMENT AND Q...
# 3                     RADIATION ACTIVATED WELL TREATMENT
# 4      METHOD AND DEVICE FOR PRODUCING WASTE PLASTIC ...
# ...                                                  ...
# 13092     Methods of preparing a polymerization catalyst
# 13093  Aromatization catalyst comprising prolongated ...
# 13094                          PRODUCTION OF ACETIC ACID
# 13095    REDUCED COLOR MOLYBDENUM-CONTAINING COMPOSITION
# 13096           Catalyst and its use in desulphurisation
#
#                                                       요약  \
# 0      A method of stimulating a hydrocarbon-bearing ...
# 1      A hydrocarbon compound and carbon monoxide are...
# 2      A process for quantifying CO2 sequestration wi...
# 3      A well treatment composition may include a cap...
# 4      The present disclosure provides a method for p...
# ...                                                  ...
# 13092  A method comprising (a) contacting a support a...
# 13093  A prolongated silica bound zeolite support com...
# 13094  PROBLEM TO BE SOLVED: To solve the problems of...
# 13095  PROBLEM TO BE SOLVED: To provide a novel metho...
# 13096  A catalyst is provided comprising nickel in a ...
#
#                                                      출원인  출원인국가  \
# 0      saudi arabian oil company|aramco services company  SA|US
# 1                   chevron phillips chemical company lp     US
# 2      saudi arabian oil company|aramco services company  SA|US
# 3       saudi arabian oil company|aramco innovations llc  SA|RU
# 4       sk innovation co., ltd.|sk geo centric co., ltd.  KR|KR
# ...                                                  ...    ...
# 13092               chevron phillips chemical company lp     US
# 13093               chevron phillips chemical company lp     US
# 13094                                   bp chemicals ltd     GB
# 13095                             chevron oronite co llc     US
# 13096                                  shell oil company     US
#
#                              출원인대표명  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 13092  CHEVRON PHILLIPS CHEMICAL LP
# 13093  CHEVRON PHILLIPS CHEMICAL LP
# 13094                           NaN
# 13095                           NaN
# 13096                  SHELL OIL CO
#
#                                                      발명자  \
# 0      KARADKAR, Prasad, Baburao|HARBI, Bader, G.|BAT...
# 1      MCDANIEL, Max, P.|REFVIK, Mitchell, D.|PRAETOR...
# 2                   AL-QASIM, Abdulaziz, S.|KOKAL, Sunil
# 3                ZHARNIKOV, Timur|ORLOV, Maxim|CHEN, Tao
# 4      JO, Sanghwan|KANG, Sookil|LEE, Howon|JUNG, Jae...
# ...                                                  ...
# 13092  Benham; Elizabeth A.|McDaniel; Max P.|Collins;...
# 13093                                  Khare; Gyanesh P.
# 13094  COOK JOHN|ELLIS BRIAN|HOWARD PHILIP|JONES MICH...
# 13095               RUHE WILLIAM R JR|ONOPCHENKO ANATOLI
# 13096               Mesters; Carolus Matthias Anna Maria
#
#                       발명자국가  \
# 0                  SA|SA|SA
# 1      US|US|US|US|US|US|US
# 2                     SA|SA
# 3                  RU|RU|SA
# 4         KR|KR|KR|KR|KR|KR
# ...                     ...
# 13092           US|US|US|US
# 13093                    US
# 13094                   NaN
# 13095                   NaN
# 13096                    NL
#
#                                                   국제특허분류  ... Genealogy수  \
# 0      C09K-008/60, C09K-008/68, C09K-008/70, C09K-00...  ...        NaN
# 1      C07B-041/06, C07C-045/49, B01J-023/68, C07C-02...  ...        NaN
# 2                  E21B-041/00, E21B-049/08, E21B-043/16  ...        NaN
# 3      C09K-008/03, C09K-008/524, C09K-008/528, C09K-...  ...        NaN
# 4                  C10G-001/10, C10G-001/00, C10G-025/00  ...        NaN
# ...                                                  ...  ...        ...
# 13092  B01J-021/00, B01J-023/00, C08F-110/02, C08F-00...  ...        2.0
# 13093              C07C-005/10, C07C-005/00, C07C-002/00  ...        2.0
# 13094  C07C-051/215, C07C-053/08, C07C-051/25, C07C-0...  ...        NaN
# 13095  C10M-169/04, C10M-101/02, C10M-107/02, C10M-12...  ...        NaN
# 13096  C10G-045/04, C10G-045/60, B01J-023/00, B01J-02...  ...        3.0
#
#            패밀리 번호 전용실시권자 통상실시권자  \
# 0             NaN    NaN    NaN
# 1             NaN    NaN    NaN
# 2             NaN    NaN    NaN
# 3             NaN    NaN    NaN
# 4             NaN    NaN    NaN
# ...           ...    ...    ...
# 13092  42224777.0    NaN    NaN
# 13093  40427891.0    NaN    NaN
# 13094  10838289.0    NaN    NaN
# 13095  29582904.0    NaN    NaN
# 13096  26951941.0    NaN    NaN
#
#                                             INPADOC패밀리국가  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 13092                      BR,CN,CO,EP,ES,KR,MX,SG,US,WO
# 13093                                     CN,EP,JP,US,WO
# 13094  AT,AU,BR,CA,CN,DE,EP,ES,GB,ID,JP,KR,MY,NO,RS,R...
# 13095                                  CA,DE,EP,JP,SG,US
# 13096  AP,AR,AT,AU,BG,BR,CA,CN,CO,CZ,DE,DK,EA,EC,EP,E...
#
#                                              Simple패밀리국가  소유권이전여부  소유권최종양도일  \
# 0                                                    NaN      NaN       NaN
# 1                                                    NaN      NaN       NaN
# 2                                                    NaN      NaN       NaN
# 3                                                    NaN      NaN       NaN
# 4                                                    NaN      NaN       NaN
# ...                                                  ...      ...       ...
# 13092                      BR,CN,CO,EP,ES,KR,MX,SG,US,WO        N       NaN
# 13093                                     CN,EP,JP,US,WO        N       NaN
# 13094  AT,AU,BR,CA,CN,DE,EP,ES,GB,ID,JP,KR,MY,NO,RS,R...      NaN       NaN
# 13095                                  CA,DE,EP,JP,SG,US      NaN       NaN
# 13096                               AT,AU,DE,EP,JP,US,WO        N       NaN
#
#                                                특허전문 Link  \
# 0      https://service.wisdomain.net/FullTextService/...
# 1      https://service.wisdomain.net/FullTextService/...
# 2      https://service.wisdomain.net/FullTextService/...
# 3      https://service.wisdomain.net/FullTextService/...
# 4      https://service.wisdomain.net/FullTextService/...
# ...                                                  ...
# 13092  https://service.wisdomain.net/FullTextService/...
# 13093  https://service.wisdomain.net/FullTextService/...
# 13094  https://service.wisdomain.net/FullTextService/...
# 13095  https://service.wisdomain.net/FullTextService/...
# 13096  https://service.wisdomain.net/FullTextService/...
#
#                                                companies
# 0      [aramco services company, saudi arabian oil co...
# 1                 [chevron phillips chemical company lp]
# 2      [aramco services company, saudi arabian oil co...
# 3      [aramco innovations llc, saudi arabian oil com...
# 4      [sk geo centric co., ltd., sk innovation co., ...
# ...                                                  ...
# 13092             [chevron phillips chemical company lp]
# 13093             [chevron phillips chemical company lp]
# 13094                                 [bp chemicals ltd]
# 13095                           [chevron oronite co llc]
# 13096                                [shell oil company]
#
# [12975 rows x 64 columns]

# %%
sum(df['특허평가등급'].isna())
# Out:
# 3914

# %%
sum(df['특허평가점수'].isna())
# Out:
# 3914

# %%
sum(df['자국피인용횟수'].isna())
# Out:
# 6150

# %%
sum(df['자국인용횟수'].isna())
# Out:
# 6039

# %%
#개수 13308개

# 출원일을 가지고 한다. (아마 1년단위)
sum(df['출원일'].isna())
# Out:
# 0

# %%
from datetime import datetime

df['출원일_datetime'] = [datetime.strptime(df['출원일'].iloc[i], '%Y.%m.%d') for i in range(len(df))]

# %%
min(df['출원일_datetime'])
# Out:
# Timestamp('2011-01-03 00:00:00')

# %% [markdown]
# ### Applied Rules
# 1. Company Name Matching: Assign values based on the presence of a company's name or a significant part of its name. For example, any value containing "SK" or variations like "SK Geo Centric" were assigned to "SK".
#
# 2. Abbreviations and Variations: Recognize and assign based on common abbreviations or variations of company names, such as "Sinopec" for "China Petroleum & Chemical Corp".
#
# 3. Subsidiaries or Divisions: Assign values mentioning known subsidiaries or divisions to the parent company, like "Chevron Phillips" to "Chevron Corp".
#
# 4. Geographical Indicators: Assign based on geographical names closely associated with a company, such as values containing "Saudi" or "Aramco" to "Saudi Arabian Oil Co".
#
# 5. Correction of Mistakes: Correct and assign values with minor spelling mistakes, such as "Suadi Arabian Oil Company" to "Saudi Arabian Oil Co".
#
# 6. Explicit Assignments: Directly assign specific values to certain companies or categories, like assigning "Beijing Research Institute of Chemical Industry" to "China Petroleum & Chemical Corp".
#
# 7. University Category: Assign educational institutions and variations of the word "university" (in different languages) to a new "University" category.
#
# 8. Miscellaneous Category: Assign values that do not clearly fit into any specific company or category to "Miscellaneous" for further review.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def categorize_company(names, companies_variations):
    result = []
    for name in names:
        category_assigned = False
        for category, variations in companies_variations.items():
            if any(name.lower() in variation.lower() for variation in variations):
                if category == "Miscellaneous":
                    result.append(name)
                else:
                    result.append(category)
                category_assigned = True
                break
        if not category_assigned:
            result.append(name)
    return result


latest_file_path = 'rules_assigning_companies.txt'
data = []
with open(latest_file_path, 'r', encoding='utf-8') as file:
    current_category = ""
    for line in file:
        if line.endswith(":\n"):
            current_category = line[:-2]
        elif line.strip():
            data.append([current_category, line.strip()])

rules = pd.DataFrame(data, columns=["Category", "Name"])
rules_dict = rules.groupby('Category')['Name'].apply(list).to_dict()
print(rules_dict["17. SK"])
print(rules_dict.items())
print(rules_dict.keys())


df['companies'] = df['출원인'].apply(lambda x: list(sorted(set(x.split('|')))))
df['companies_categorized'] = df['companies'].apply(lambda x: categorize_company(x, rules_dict))

category_counts = df['companies_categorized'].explode().value_counts()
print(category_counts[:30])


# Visualization
plt.figure(figsize=(12, 8))
sns.barplot(x=category_counts[:15].values, y=category_counts[:15].index, palette="muted")
plt.title("Number of Entries per Category")
plt.xlabel("Number of Entries")
plt.ylabel("Category")
plt.show()
# Out:
# ['sabic sk nexlene company pte. ltd.', 'sk earthon co., ltd.', 'sk energy co ltd', 'sk energy co., ltd.', 'sk enmove co., ltd', 'sk gc americas inc.', 'sk geo centric co., ltd.', 'sk global chemical co ltd', 'sk global chemical co, ltd.', 'sk global chemical co., ltd.', 'sk gloval chemical co., ltd.', 'sk ie technology co ltd', 'sk ie technology co. , ltd.', 'sk ie technology co., ltd.', 'sk inc.', 'sk incheon petrochem co., ltd.', 'sk innovation  co., ltd.', 'sk innovation co ltd', 'sk innovation co, ltd', 'sk innovation co, ltd.', 'sk innovation co. ltd.', 'sk innovation co., lt.d', 'sk innovation co., ltd', 'sk innovation co., ltd.', 'sk innovation co.,ltd', 'sk innovation co.,ltd.', 'sk innovations co., ltd.', 'sk lubricants co., ltd.', 'sk on co, ltd.', 'sk on co., ltd', 'sk on co., ltd.', 'sk-materials co., ltd.', 'skgc americas inc.']
# dict_items([('1. Saudi Arabian Oil Co', ['aramco far east (beijing) business service co. ltd (abs)', 'aramco far east (beijing) business service co. ltd.', 'aramco far east (beijing) business services co., ltd.', 'aramco innovations llc', 'aramco overseas company b.v.', 'aramco overseas company uk ltd', 'aramco overseas company uk ltd.', 'aramco service comapny', 'aramco services company', 'aramco sevices company', 'king fahd university of petroleum & minerals, saudi arabian oil company', 'saidi arabian oil company', 'saud arabian oil company', 'saudi  arabian oil company', 'saudi arabia oil company', 'saudi arabian company', 'saudi arabian oil co', 'saudi arabian oil comapny', 'saudi arabian oil comoanv', 'saudi arabian oil comoany', 'saudi arabian oil company', 'saudi arabian oil company and', 'saudi arabian oil company, dhahran, saudi arabia', 'saudi arabian oil companyd', 'saudi arabian oil compay', 'saudi arabian oil compnay', 'saudi arabian oil componv', 'saudi arabian oil conpany', 'saudi arabian oli company', 'saudi arabian upstream technology company', 'saudi aramco technologies company', 'saudi arbian oil company', 'saudia arabian oil company', 'suadi arabian oil company']), ('10. China Petroleum & Chemical Corp', ['beiging research institute of chemical industry, china petroleum & chemical corporation', 'beijing reaearch institute of chemical industry, china petroleum & chemical corporation', 'beijing reasearch institute of chemical industry, china petroleum & chemical corporation', 'beijing research inst of chemical industry china petroleum & chemical corp', 'beijing research institute of chemical industry', 'beijing research institute of chemical industry china petroleum & chemical corporation', 'beijing research institute of chemical industry, china petroleum & chemical coporation', 'beijing research institute of chemical industry, china petroleum & chemical corp', 'beijing research institute of chemical industry, china petroleum & chemical corp.', 'beijing research institute of chemical industry, china petroleum & chemical corporatin', 'beijing research institute of chemical industry, china petroleum & chemical corporation', 'beijing research institute of chemical industry, china petroleum & chimical corporation', 'beijing research institute of chemical industry, china petroleum & chrmical corporation', 'beijing research institute of chemical industry, china petroleum and chemical corporation', 'beijing research institute of chemical industry, china petrolium & chemical corporation', 'china petrolum & chemical corporation', 'china petroleum & chamical corporation', 'china petroleum & cheimcal corporation', 'china petroleum & chemcial corporation', 'china petroleum & chemical  corporation', 'china petroleum & chemical corp', 'china petroleum & chemical corp.', 'china petroleum & chemical corporation', 'china petroleum & chemical corporation and beijing research institute of chemical industry', 'china petroleum & chemical corporation beijing research institute of chemical industry', 'china petroleum & chemical corporation beijing research institute of chemical industry, china petroleum & chemical corporation', 'china petroleum & chemical corporation exploration & production research institute', 'china petroleum & chemical corporation ltd', 'china petroleum & chemical corporation ltd gas storage branch', 'china petroleum & chemical corporation ltd.', 'china petroleum & chemical corporation qingdao research institute of safety engineering', 'china petroleum & chemical corporation southwest oil & gas company', 'china petroleum chemical corporation', 'china research institute of petroleum processing, sinopec', 'dalian research institute of petroleum and petrochemicals, sinopec corp.', 'drilling engineering echnology research institute of sinopec zhongyuan petroleum engineering co., lt', 'drilling engineering technology research inst. of sinopec zhongyuan petroleum engineering co., ltd', 'drilling engineering technolog ...
# dict_keys(['1. Saudi Arabian Oil Co', '10. China Petroleum & Chemical Corp', '13. PetroChina Co Ltd', '14. Eni S.p.A.', '15. BP p.l.c.', '16. Suncor Energy Inc', '17. SK', '2. Petrobras', '3. PJSC LUKOIL', '4. Exxon Mobil Corp', '6. TotalEnergies SE', '7. Equinor ASA', '8. Chevron Corp', '9. Shell plc', 'Miscellaneous', 'Senai', 'University'])
# companies_categorized
# 1. Saudi Arabian Oil Co                                              4890
# 9. Shell plc                                                         2380
# 8. Chevron Corp                                                      2357
# 17. SK                                                               1471
# 10. China Petroleum & Chemical Corp                                  1395
# 15. BP p.l.c.                                                         688
# University                                                            507
# 2. Petrobras                                                          376
# 14. Eni S.p.A.                                                        361
# 6. TotalEnergies SE                                                   341
# 13. PetroChina Co Ltd                                                 295
# 7. Equinor ASA                                                        237
# 16. Suncor Energy Inc                                                  88
# 4. Exxon Mobil Corp                                                    56
# schlumberger technology corporation                                    33
# ifp energies nouvelles                                                 27
# halliburton energy services, inc.                                      21
# uop llc                                                                19
# jgc catalysts and chemicals ltd.                                       18
# triad national security, llc                                           16
# Senai                                                                  15
# centre national de la recherche scientifique                           13
# japan cooperation center petroleum                                     13
# sabic global technologies b.v.                                         11
# georgia tech research corporation                                      10
# versalis s.p.a.                                                        10
# shanghai advanced research institute, chinese academy of sciences       8
# dalian institute of chemical physics, chinese academy of sciences       8
# wireless instrumentation systems as                                     8
# marathon oil canada corporation                                         7
# Name: count, dtype: int64

# %%
unique_companies = df['companies_categorized'].apply(lambda x : set(x))

# %%
category_counts = df['companies_categorized'].explode().value_counts()
top14 = category_counts.index[:14]

# %%
unique_companies
# Out:
# 0        {1. Saudi Arabian Oil Co}
# 1                {8. Chevron Corp}
# 2        {1. Saudi Arabian Oil Co}
# 3        {1. Saudi Arabian Oil Co}
# 4                         {17. SK}
#                    ...
# 13426            {8. Chevron Corp}
# 13427            {8. Chevron Corp}
# 13428              {15. BP p.l.c.}
# 13429            {8. Chevron Corp}
# 13430            {8. Chevron Corp}
# Name: companies_categorized, Length: 13308, dtype: object

# %%
n=0
for uniq_set in unique_companies:
    if len(uniq_set)>1:
        appropriate = True
        for obj in list(uniq_set):
            if obj =='University' or obj not in top14:
                appropriate=False
                break
            
        if appropriate:
            print(uniq_set)
            n+=1
            
print(n)
# Out:
# {'1. Saudi Arabian Oil Co', '10. China Petroleum & Chemical Corp'}
# {'4. Exxon Mobil Corp', '8. Chevron Corp'}
# {'4. Exxon Mobil Corp', '8. Chevron Corp'}
# {'4. Exxon Mobil Corp', '8. Chevron Corp'}
# {'4. Exxon Mobil Corp', '8. Chevron Corp'}
# {'1. Saudi Arabian Oil Co', '2. Petrobras'}
# {'15. BP p.l.c.', '16. Suncor Energy Inc'}
# {'4. Exxon Mobil Corp', '8. Chevron Corp'}
# {'6. TotalEnergies SE', '8. Chevron Corp'}
# {'4. Exxon Mobil Corp', '8. Chevron Corp'}
# {'6. TotalEnergies SE', '8. Chevron Corp'}
# {'6. TotalEnergies SE', '8. Chevron Corp'}
# 12

# %%
df['unique_companies_set']=df['companies_categorized'].apply(lambda x : set(x))
df_expanded  = df.explode('unique_companies_set')
df_expanded=df_expanded.dropna(subset=['국제특허분류'])
df_expanded['ipc_code'] = df_expanded['국제특허분류'].apply(lambda x: x.split(','))
df_explode =df_expanded.explode(['ipc_code'])
df_explode['ipc_code']
df_explode['ipc_code_front'] = df_explode['ipc_code'].apply(lambda x : x.split('-')[0]).apply(lambda x : x.strip())

df_explode
# Out:
#         일련번호            번호                                                 명칭  \
# 0          1  WO23196956A1             FOAM STABILIZATION USING NANOPARTICLES
# 0          1  WO23196956A1             FOAM STABILIZATION USING NANOPARTICLES
# 0          1  WO23196956A1             FOAM STABILIZATION USING NANOPARTICLES
# 0          1  WO23196956A1             FOAM STABILIZATION USING NANOPARTICLES
# 0          1  WO23196956A1             FOAM STABILIZATION USING NANOPARTICLES
# ...      ...           ...                                                ...
# 13428  13465     USRE44206  Oxidation process for the production of carbox...
# 13428  13465     USRE44206  Oxidation process for the production of carbox...
# 13429  13466     US8404912        Process for making high VI lubricating oils
# 13429  13466     US8404912        Process for making high VI lubricating oils
# 13430  13470     US8222473                   Isomerization of light paraffins
#
#                                                       요약  \
# 0      A method of stimulating a hydrocarbon-bearing ...
# 0      A method of stimulating a hydrocarbon-bearing ...
# 0      A method of stimulating a hydrocarbon-bearing ...
# 0      A method of stimulating a hydrocarbon-bearing ...
# 0      A method of stimulating a hydrocarbon-bearing ...
# ...                                                  ...
# 13428  An oxidation process for the production of alk...
# 13428  An oxidation process for the production of alk...
# 13429  A process for making a high VI lubricating bas...
# 13429  A process for making a high VI lubricating bas...
# 13430  A process for isomerizing light paraffins usin...
#
#                                                      출원인  출원인국가  \
# 0      saudi arabian oil company|aramco services company  SA|US
# 0      saudi arabian oil company|aramco services company  SA|US
# 0      saudi arabian oil company|aramco services company  SA|US
# 0      saudi arabian oil company|aramco services company  SA|US
# 0      saudi arabian oil company|aramco services company  SA|US
# ...                                                  ...    ...
# 13428                               bp chemicals limited     GB
# 13428                               bp chemicals limited     GB
# 13429                                chevron u.s.a. inc.     US
# 13429                                chevron u.s.a. inc.     US
# 13430                                chevron u.s.a. inc.     US
#
#                  출원인대표명                                                발명자  \
# 0                   NaN  KARADKAR, Prasad, Baburao|HARBI, Bader, G.|BAT...
# 0                   NaN  KARADKAR, Prasad, Baburao|HARBI, Bader, G.|BAT...
# 0                   NaN  KARADKAR, Prasad, Baburao|HARBI, Bader, G.|BAT...
# 0                   NaN  KARADKAR, Prasad, Baburao|HARBI, Bader, G.|BAT...
# 0                   NaN  KARADKAR, Prasad, Baburao|HARBI, Bader, G.|BAT...
# ...                 ...                                                ...
# 13428  BP CHEMICALS LTD  Ferguson; Ewen James|Lucy; Andrew Richard|Robe...
# 13428  BP CHEMICALS LTD  Ferguson; Ewen James|Lucy; Andrew Richard|Robe...
# 13429   CHEVRON USA INC                             Miller; Stephen Joseph
# 13429   CHEVRON USA INC                             Miller; Stephen Joseph
# 13430   CHEVRON USA INC  Chen; Cong-Yan|Ouyang; Xiaoying|Davis; Tracy M...
#
#                 발명자국가                                             국제특허분류  ...  \
# 0            SA|SA|SA  C09K-008/60, C09K-008/68, C09K-008/70, C09K-00...  ...
# 0            SA|SA|SA  C09K-008/60, C09K-008/68, C09K-008/70, C09K-00...  ...
# 0            SA|SA|SA  C09K-008/60, C09K-008/68, C09K-008/70, C09K-00...  ...
# 0            SA|SA|SA  C09K-008/60, C09K-008/68, C09K-008/70, C09K-00...  ...
# 0            SA|SA|SA  C09K-008/60, C09K-008/68, C09K-008/70, C09K-00...  ...
# ...               ...                                                ...  ...
# 13428  GB|GB|GB|GB|GB                           C07C-067/00, C07C-051/16  ...
# 13428  GB|GB|GB|GB|GB                           C07C-067/00, C07C-051/16  ...
# 13429              US                           C10G-047/00, C07C-005/13  ...
# 13429              US                           C10G-047/00, C07C-005/13  ...
# 13430     US|US|US|US                                        C07C-005/27  ...
#
#                                            Simple패밀리국가 소유권이전여부 소유권최종양도일  \
# 0                                                  NaN     NaN      NaN
# 0                                                  NaN     NaN      NaN
# 0                                                  NaN     NaN      NaN
# 0                                                  NaN     NaN      NaN
# 0                                                  NaN     NaN      NaN
# ...                                                ...     ...      ...
# 13428  AT,BR,CN,EP,ES,GB,JP,KR,MY,NO,RS,RU,TW,UA,US,WO       N      NaN
# 13428  AT,BR,CN,EP,ES,GB,JP,KR,MY,NO,RS,RU,TW,UA,US,WO       N      NaN
# 13429                       CA,CN,EP,IN,JP,KR,SG,US,WO       N      NaN
# 13429                       CA,CN,EP,IN,JP,KR,SG,US,WO       N      NaN
# 13430                                            US,WO       N      NaN
#
#                                                특허전문 Link  \
# 0      https://service.wisdomain.net/FullTextService/...
# 0      https://service.wisdomain.net/FullTextService/...
# 0      https://service.wisdomain.net/FullTextService/...
# 0      https://service.wisdomain.net/FullTextService/...
# 0      https://service.wisdomain.net/FullTextService/...
# ...                                                  ...
# 13428  https://service.wisdomain.net/FullTextService/...
# 13428  https://service.wisdomain.net/FullTextService/...
# 13429  https://service.wisdomain.net/FullTextService/...
# 13429  https://service.wisdomain.net/FullTextService/...
# 13430  https://service.wisdomain.net/FullTextService/...
#
#                                                companies 출원일_datetime  \
# 0      [aramco services company, saudi arabian oil co...   2023-04-07
# 0      [aramco services company, saudi arabian oil co...   2023-04-07
# 0      [aramco services company, saudi arabian oil co...   2023-04-07
# 0      [aramco services company, saudi arabian oil co...   2023-04-07
# 0      [aramco services company, saudi arabian oil co...   2023-04-07
# ...                                                  ...          ...
# 13428                             [bp chemicals limited]   2011-05-16
# 13428                             [bp chemicals limited]   2011-05-16
# 13429                              [chevron u.s.a. inc.]   2012-05-09
# 13429                              [chevron u.s.a. inc.]   2012-05-09
# 13430                              [chevron u.s.a. inc.]   2011-12-22
#
#                                    companies_categorized  \
# 0      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...
# 0      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...
# 0      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...
# 0      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...
# 0      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...
# ...                                                  ...
# 13428                                    [15. BP p.l.c.]
# 13428                                    [15. BP p.l.c.]
# 13429                                  [8. Chevron Corp]
# 13429                                  [8. Chevron Corp]
# 13430                                  [8. Chevron Corp]
#
#           unique_companies_set      ipc_code ipc_code_front
# 0      1. Saudi Arabian Oil Co   C09K-008/60           C09K
# 0      1. Saudi Arabian Oil Co   C09K-008/68           C09K
# 0      1. Saudi Arabian Oil Co   C09K-008/70           C09K
# 0      1. Saudi Arabian Oil Co   C09K-008/86           C09K
# 0      1. Saudi Arabian Oil Co   C09K-008/94           C09K
# ...                        ...           ...            ...
# 13428            15. BP p.l.c.   C07C-067/00           C07C
# 13428            15. BP p.l.c.   C07C-051/16           C07C
# 13429          8. Chevron Corp   C10G-047/00           C10G
# 13429          8. Chevron Corp   C07C-005/13           C07C
# 13430          8. Chevron Corp   C07C-005/27           C07C
#
# [64249 rows x 69 columns]

# %%
for company in top14:
    print(company)
    print(df_explode[df_explode['unique_companies_set'] == company]['ipc_code_front'].value_counts()[:5])
    print('============================')
# Out:
# 1. Saudi Arabian Oil Co
# ipc_code_front
# E21B    5297
# B01J    1754
# C10G    1488
# C09K    1388
# G01N    1217
# Name: count, dtype: int64
# ============================
# 9. Shell plc
# ipc_code_front
# B01J    1746
# C07C     970
# C10G     876
# E21B     773
# C10L     484
# Name: count, dtype: int64
# ============================
# 8. Chevron Corp
# ipc_code_front
# B01J    1862
# E21B     853
# C08F     820
# C10M     819
# C10G     697
# Name: count, dtype: int64
# ============================
# 17. SK
# ipc_code_front
# H01M    2428
# B01J     369
# C07C     241
# C10G     201
# C08G     168
# Name: count, dtype: int64
# ============================
# 10. China Petroleum & Chemical Corp
# ipc_code_front
# B01J    1268
# C07C     430
# C10G     334
# C08F     311
# B01D     192
# Name: count, dtype: int64
# ============================
# 15. BP p.l.c.
# ipc_code_front
# C07C    384
# E21B    355
# B01J    324
# G01V    218
# C10L    112
# Name: count, dtype: int64
# ============================
# University
# ipc_code_front
# B01J    718
# E21B    154
# C07C    153
# C01B    148
# G01N    128
# Name: count, dtype: int64
# ============================
# 2. Petrobras
# ipc_code_front
# B01J    236
# E21B    229
# F16L     73
# G01N     64
# B01D     62
# Name: count, dtype: int64
# ============================
# 14. Eni S.p.A.
# ipc_code_front
# B01J    189
# C10G    148
# E21B    123
# H01L    101
# C07C     70
# Name: count, dtype: int64
# ============================
# 6. TotalEnergies SE
# ipc_code_front
# E21B    149
# G01V    142
# B01D     92
# G01N     91
# H01L     63
# Name: count, dtype: int64
# ============================
# 13. PetroChina Co Ltd
# ipc_code_front
# B01J    232
# E21B    173
# C08F    102
# G01N     98
# G01V     90
# Name: count, dtype: int64
# ============================
# 7. Equinor ASA
# ipc_code_front
# E21B    304
# G01V     92
# B63B     58
# G01N     48
# F16L     43
# Name: count, dtype: int64
# ============================
# 16. Suncor Energy Inc
# ipc_code_front
# C10G    54
# A01N    51
# E21B    48
# C02F    40
# B01D    13
# Name: count, dtype: int64
# ============================
# 4. Exxon Mobil Corp
# ipc_code_front
# B01J    31
# C08F    31
# E21B    29
# C07C    17
# C10M    16
# Name: count, dtype: int64
# ============================

# %%
len(category_counts[14:])
# Out:
# 371

# %%
df.columns
# Out:
# Index(['일련번호', '번호', '명칭', '요약', '출원인', '출원인국가', '출원인대표명', '발명자', '발명자국가',
#        '국제특허분류', '공통특허분류', '미국특허분류', '출원번호', '출원일', '공개번호', '공개일', '공고번호',
#        '공고일', '등록번호', '등록일', '우선권번호', '국제출원번호', '국제출원일', '국제공개번호', '국제공개일',
#        'INPADOC 패밀리', 'Simple 패밀리', '심사관', '대리인', '지정국가', '독립 청구항수', '전체 청구항수',
#        '대표 청구항', '대표 청구항(원문)', '권리 현황', '최종 상태', '현재소유자', '권리만료예상일', '자국인용특허',
#        '외국인용특허', '자국피인용특허', '자국인용횟수', '자국피인용횟수', '특허평가등급', '특허평가점수',
#        '발명자평가평균등급', '발명자평가평균점수', 'FI', 'F-Term', 'INPADOC패밀리수',
#        'INPADOC패밀리국가수', 'Simple패밀리수', 'Simple패밀리국가수', '발명자수', 'Genealogy수',
#        '패밀리 번호', '전용실시권자', '통상실시권자', 'INPADOC패밀리국가', 'Simple패밀리국가', '소유권이전여부',
#        '소유권최종양도일', '특허전문 Link', 'companies', '출원일_datetime',
#        'companies_categorized'],
#       dtype='object')

# %%
sum(df['공개일'].isna())
# Out:
# 333

# %%
lv_df = df[['companies_categorized','공개일']].copy()
lv_df['공개일'] = pd.to_datetime(lv_df['공개일'], errors='coerce')

# '공개일' 열에서 연도 정보를 추출
lv_df['연월'] = lv_df['공개일'].dt.year*100+lv_df['공개일'].dt.month
lv_df['연월']
# Out:
# 0        202310.0
# 1        202310.0
# 2        202310.0
# 3        202310.0
# 4        202310.0
#            ...
# 13426         NaN
# 13427         NaN
# 13428         NaN
# 13429         NaN
# 13430         NaN
# Name: 연월, Length: 13308, dtype: float64

# %%
lv_df['companies_categorized_unique'] = lv_df['companies_categorized'].apply(lambda x : list(set(x)))

# %%
lv_df = df[['companies_categorized','공개일']].copy()

# %%
lv_df = lv_df.dropna() # 연도 없는 거 지우고~

# %%
lv_df = lv_df.explode('companies_categorized_unique') [['연월','companies_categorized_unique']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'companies_categorized_unique'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Ksunwoo\Desktop\23-2\기예인\dev\tech_pred\top_oil_data.ipynb Cell 39 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> lv_df = lv_df.explode('companies_categorized_unique') [['연월','companies_categorized_unique']]
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:8881, in DataFrame.explode(self, column, ignore_index)
#    8879 df = self.reset_index(drop=True)
#    8880 if len(columns) == 1:
# -> 8881     result = df[columns[0]].explode()
#    8882 else:
#    8883     mylen = lambda x: len(x) if (is_list_like(x) and len(x) > 0) else 1
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'companies_categorized_unique'

# %%
lv_df['companies_categorized_unique'].value_counts()[:14]
# Out:
# companies_categorized_unique
# 1. Saudi Arabian Oil Co                4490
# 8. Chevron Corp                        2188
# 9. Shell plc                           1939
# 17. SK                                 1121
# 10. China Petroleum & Chemical Corp     726
# 15. BP p.l.c.                           663
# University                              481
# 2. Petrobras                            376
# 14. Eni S.p.A.                          361
# 6. TotalEnergies SE                     341
# 13. PetroChina Co Ltd                   290
# 7. Equinor ASA                          235
# 16. Suncor Energy Inc                    88
# 4. Exxon Mobil Corp                      56
# Name: count, dtype: int64

# %%
top_company_list =list(lv_df['companies_categorized_unique'].value_counts()[:14].index)

# %%
lv_df =lv_df[lv_df['companies_categorized_unique'].isin(top_company_list)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'companies_categorized_unique'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Ksunwoo\Desktop\23-2\기예인\dev\tech_pred\top_oil_data.ipynb Cell 42 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> lv_df =lv_df[lv_df['companies_categorized_unique'].isin(top_company_list)]
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'companies_categorized_unique'

# %%
lv_df = lv_df.groupby(['companies_categorized_unique','연월']).size().unstack().fillna(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Ksunwoo\Desktop\23-2\기예인\dev\tech_pred\top_oil_data.ipynb Cell 44 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> lv_df = lv_df.groupby(['companies_categorized_unique','연월']).size().unstack().fillna(0)
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\grouper.py:985, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     983         in_axis, level, gpr = False, gpr, None
#     984     else:
# --> 985         raise KeyError(gpr)
#     986 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     987     # Add key to exclusions
#     988     exclusions.add(gpr.key)
#
# KeyError: 'companies_categorized_unique'

# %%
lv_df.sum(axis=0)
# Out:
# companies_categorized    [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...
# 공개일                      2023.10.122023.10.122023.10.122023.10.122023.1...
# dtype: object

# %%
lv_df
# Out:
#                                    companies_categorized         공개일
# 0      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...  2023.10.12
# 1                                      [8. Chevron Corp]  2023.10.12
# 2      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...  2023.10.12
# 3      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...  2023.10.12
# 4                                       [17. SK, 17. SK]  2023.10.12
# ...                                                  ...         ...
# 13092                                  [8. Chevron Corp]  2011.06.09
# 13093                                  [8. Chevron Corp]  2011.06.09
# 13094                                    [15. BP p.l.c.]  2011.06.02
# 13095                                  [8. Chevron Corp]  2011.05.19
# 13096                                     [9. Shell plc]  2011.05.12
#
# [12975 rows x 2 columns]

# %%
import networkx as nx
import numpy as np
G = nx.Graph()

# 노드 추가
G.add_nodes_from(lv_df.index)

# 간선 추가
for company1 in lv_df.index:
    for company2 in lv_df.index:
        if company1 != company2:
            interaction = lv_df.loc[company1] * lv_df.loc[company2]
            G.add_edge(company1, company2, weight=interaction.sum())

# 네트워크 시각화
pos = nx.spring_layout(G)
labels = {node: node for node in G.nodes()}
sizes = [G.degree(node) * 50 for node in G.nodes()]
plt.figure(figsize=(12, 8))  # 그래프의 크기 조정

# 간선의 두께를 더 크게 조정
edge_width = [np.log(edata['weight'])/10 for _, _, edata in G.edges(data=True)]

nx.draw_networkx_nodes(G, pos, node_size=sizes, node_color='skyblue')
nx.draw_networkx_edges(G, pos, width=edge_width)
nx.draw_networkx_labels(G, pos, labels, font_size=8)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\computation\expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: can't multiply sequence by non-int of type 'list'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\Users\Ksunwoo\Desktop\23-2\기예인\dev\tech_pred\top_oil_data.ipynb Cell 47 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#X64sZmlsZQ%3D%3D?line=9'>10</a>     for company2 in lv_df.index:
#      <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#X64sZmlsZQ%3D%3D?line=10'>11</a>         if company1 != company2:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#X64sZmlsZQ%3D%3D?line=11'>12</a>             interaction = lv_df.loc[company1] * lv_df.loc[company2]
#      <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#X64sZmlsZQ%3D%3D?line=12'>13</a>             G.add_edge(company1, company2, weight=interaction.sum())
#      <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#X64sZmlsZQ%3D%3D?line=14'>15</a> # 네트워크 시각화
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:202, in OpsMixin.__mul__(self, other)
#     200 @unpack_zerodim_and_defer("__mul__")
#     201 def __mul__(self, other):
# --> 202     return self._arith_method(other, operator.mul)
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:6112, in Series._arith_method(self, other, op)
#    6110 def _arith_method(self, other, op):
#    6111     self, other = ops.align_method_SERIES(self, other)
# -> 6112     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\base.py:1348, in IndexOpsMixin._arith_method(self, other, op)
#    1345 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1347 with np.errstate(all="ignore"):
# -> 1348     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1350 return self._construct_result(result, name=res_name)
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:232, in arithmetic_op(left, right, op)
#     228     _bool_arith_check(op, left, right)
#     230     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     231     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 232     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     234 return res_values
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:178, in _na_arithmetic_op(left, right, op, is_cmp)
#     172 except TypeError:
#     173     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     174         # For object dtype, fallback to a masked operation (only operating
#     175         #  on the non-missing values)
#     176         # Don't do this for comparisons, as that will handle complex numbers
#     177         #  incorrectly, see GH#32047
# --> 178         result = _masked_arith_op(left, right, op)
#     179     else:
#     180         raise
#
# File c:\Users\Ksunwoo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:116, in _masked_arith_op(x, y, op)
#     114     # See GH#5284, GH#5035, GH#19448 for historical reference
#     115     if mask.any():
# --> 116         result[mask] = op(xrav[mask], yrav[mask])
#     118 else:
#     119     if not is_scalar(y):
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
import numpy as np
import scipy.optimize
from scipy.integrate import odeint

# %%
time_lst = lv_df.columns
len(lv_df.index) #회사 개수 14개 (agent 개수 14개) -> parameter 196개
# Out:
# 14

# %%
yearmonth = list(range(len(time_lst)))

# %%
[i for i in range(10) if i!=7]
# Out:
# [0, 1, 2, 3, 4, 5, 6, 8, 9]

# %%
def sim(variables, t, params): # params [i*14 + j] 는  i번째 agent의 특허개수가 j번째 agent 에게 미치는 영향 
    #variables[i]는 i번째 회사의 특허 개수
    com_len = len(variables)
    result_lst =[]
    
    for i in range(len(variables)): # i 회사 index, j = 타 회사
        x = variables[i]
        dxdt = x * (params[i*com_len+i] - sum([variables[j]*params[j*com_len+i] for j in range(com_len) if j!=i]) )
        
        result_lst.append(dxdt)
        
    return result_lst

# %%
def loss_function(params, yearmonth,variables):
    print(variables)
    y0 = [variable[0] for variable in variables]
    t= np.linspace(yearmonth[0],yearmonth[-1],num = len(yearmonth))
    
    output = odeint(sim,y0,t,args = (params,))
    loss = 0
    
    for i in range(len(yearmonth)):
        for j in range(len(variables)):
            data_value = variables[j][i]
            model_value = output[i,j]
            
            loss+= (data_value-model_value)**2
    return loss

# %%
[variable[0] for variable in lv_df.values]
# Out:
# [['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['17. SK', '17. SK'],
#  ['14. Eni S.p.A.'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co', '10. China Petroleum & Chemical Corp'],
#  ['17. SK', '17. SK'],
#  ['17. SK', '17. SK'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK', '17. SK'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['8. Chevron Corp'],
#  ['17. SK', '17. SK'],
#  ['17. SK', '17. SK'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['17. SK', '17. SK'],
#  ['8. Chevron Corp'],
#  ['16. Suncor Energy Inc'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK', '17. SK'],
#  ['14. Eni S.p.A.'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['14. Eni S.p.A.'],
#  ['15. BP p.l.c.'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp', '8. Chevron Corp'],
#  ['17. SK'],
#  ['University', '1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['13. PetroChina Co Ltd', '13. PetroChina Co Ltd'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK', '17. SK'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['7. Equinor ASA'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['halliburton energy services, inc.', '2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['University', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK', '17. SK'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK', '17. SK'],
#  ['17. SK'],
#  ['14. Eni S.p.A.'],
#  ['8. Chevron Corp'],
#  ['14. Eni S.p.A.'],
#  ['8. Chevron Corp', 'University'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['14. Eni S.p.A.'],
#  ['17. SK'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['University', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['14. Eni S.p.A.'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['9. Shell plc'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['fca fiat chrysler automoveis brasil ltda',
#   'fundacao de amparo a pesquisa do estado de minas gerais - fapemig',
#   '2. Petrobras',
#   'University'],
#  ['2. Petrobras', 'University'],
#  ['University', '8. Chevron Corp'],
#  ['10. China Petroleum & Chemical Corp', 'uop llc'],
#  ['7. Equinor ASA'],
#  ['7. Equinor ASA'],
#  ['17. SK', '17. SK'],
#  ['17. SK', '17. SK'],
#  ['13. PetroChina Co Ltd'],
#  ['dalian institute of chemical physics, chinese academy of sciences',
#   '13. PetroChina Co Ltd'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['17. SK', '17. SK'],
#  ['17. SK', '17. SK'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co', 'shanks tech ltd'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['9. Shell plc'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK', '17. SK'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['17. SK', '17. SK'],
#  ['17. SK', '17. SK'],
#  ['gm flow measurement services ltd.', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras', 'University'],
#  ['9. Shell plc'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['15. BP p.l.c.'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['15. BP p.l.c.'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp', 'triad national security, llc'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['9. Shell plc'],
#  ['8. Chevron Corp', '8. Chevron Corp'],
#  ['9. Shell plc'],
#  ['10. China Petroleum & Chemical Corp', 'uop llc'],
#  ['9. Shell plc'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['13. PetroChina Co Ltd'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['7. Equinor ASA'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['7. Equinor ASA'],
#  ['7. Equinor ASA'],
#  ['7. Equinor ASA'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK', '17. SK'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['15. BP p.l.c.', 'University'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp', '8. Chevron Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['15. BP p.l.c.'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['7. Equinor ASA'],
#  ['14. Eni S.p.A.'],
#  ['9. Shell plc', '9. Shell plc'],
#  ['9. Shell plc', '9. Shell plc'],
#  ['9. Shell plc', '9. Shell plc'],
#  ['8. Chevron Corp', '8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co',
#   'trofimuk lnstitute of petroleum geology and geophysics'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['15. BP p.l.c.'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['9. Shell plc'],
#  ['14. Eni S.p.A.', 'versalis s.p.a.'],
#  ['10. China Petroleum & Chemical Corp', 'uop llc'],
#  ['10. China Petroleum & Chemical Corp', 'uop llc'],
#  ['10. China Petroleum & Chemical Corp', 'uop llc'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['14. Eni S.p.A.'],
#  ['8. Chevron Corp'],
#  ['14. Eni S.p.A.'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['landmark graphics corporation', '2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['9. Shell plc'],
#  ['1. Saudi Arabian Oil Co'],
#  ['13. PetroChina Co Ltd'],
#  ['1. Saudi Arabian Oil Co'],
#  ['7. Equinor ASA'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['15. BP p.l.c.'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['9. Shell plc'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['7. Equinor ASA'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp', '8. Chevron Corp'],
#  ['17. SK', '17. SK'],
#  ['8. Chevron Corp', 'University'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['15. BP p.l.c.'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['7. Equinor ASA'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK'],
#  ['8. Chevron Corp', '8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['17. SK'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp', '8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp', '8. Chevron Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['6. TotalEnergies SE'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['University', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp', 'halliburton energy services, inc.', 'sdg llc'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp', '8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['14. Eni S.p.A.'],
#  ['17. SK'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK'],
#  ['17. SK', '17. SK'],
#  ['17. SK', '17. SK'],
#  ['8. Chevron Corp'],
#  ['2. Petrobras'],
#  ['halliburton energy services, inc.', '1. Saudi Arabian Oil Co'],
#  ['7. Equinor ASA'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK', '17. SK'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['8. Chevron Corp', '8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['16. Suncor Energy Inc'],
#  ['1. Saudi Arabian Oil Co'],
#  ['14. Eni S.p.A.'],
#  ['17. SK'],
#  ['17. SK', '17. SK'],
#  ['17. SK', '17. SK'],
#  ['17. SK'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['9. Shell plc'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['japan cooperation center for petroleum and sustainable energy',
#   'jgc catalysts & chemicals ltd.',
#   '1. Saudi Arabian Oil Co'],
#  ['japan cooperation center for petroleum and sustainable energy',
#   'jgc catalysts & chemicals ltd.',
#   '1. Saudi Arabian Oil Co'],
#  ['japan cooperation center for petroleum and sustainable energy',
#   'jgc catalysts & chemicals ltd.',
#   '1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['7. Equinor ASA'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co',
#   'schlumberger technology b.v.',
#   'services pétroliers schlumberger'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['13. PetroChina Co Ltd'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp',
#   'University'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK', '17. SK'],
#  ['17. SK', '17. SK'],
#  ['17. SK'],
#  ['9. Shell plc'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['9. Shell plc'],
#  ['2. Petrobras', 'University'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['13. PetroChina Co Ltd'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras', 'Senai'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', 'University'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['9. Shell plc'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['14. Eni S.p.A.'],
#  ['17. SK', '17. SK'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['changqing engineering design co., ltd.', '13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK', '17. SK'],
#  ['17. SK', '17. SK'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras', 'University'],
#  ['chengdu dongwei technology co., ltd.', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['chengdu dongwei technology co., ltd', '1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['17. SK', '17. SK'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['14. Eni S.p.A.'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['7. Equinor ASA'],
#  ['14. Eni S.p.A.', 'versalis s.p.a.'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['13. PetroChina Co Ltd'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['13. PetroChina Co Ltd'],
#  ['2. Petrobras'],
#  ['2. Petrobras', 'University'],
#  ['17. SK'],
#  ['17. SK', '17. SK'],
#  ['2. Petrobras'],
#  ['8. Chevron Corp'],
#  ['10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['2. Petrobras'],
#  ['13. PetroChina Co Ltd'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras', 'University'],
#  ['2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['14. Eni S.p.A.'],
#  ['2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['University', '1. Saudi Arabian Oil Co'],
#  ['9. Shell plc'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['2. Petrobras'],
#  ['15. BP p.l.c.', 'johnson matthey davy technologies limited'],
#  ['15. BP p.l.c.', 'johnson matthey davy technologies limited'],
#  ['15. BP p.l.c.'],
#  ['15. BP p.l.c.'],
#  ['8. Chevron Corp', 'triad national security, llc'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras', 'University'],
#  ['17. SK', '17. SK'],
#  ['17. SK'],
#  ['2. Petrobras'],
#  ['2. Petrobras', 'University'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['kasab international energy services co. ltd.', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['8. Chevron Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['9. Shell plc'],
#  ['1. Saudi Arabian Oil Co', 'twi ltd.'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['8. Chevron Corp'],
#  ['9. Shell plc'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['instituto de pesquisas tecnologicas do estado de sao paulo s.a. - ipt',
#   '2. Petrobras'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['14. Eni S.p.A.'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras', 'University'],
#  ['17. SK', '17. SK'],
#  ['17. SK', '17. SK'],
#  ['17. SK', '17. SK'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['10. China Petroleum & Chemical Corp'],
#  ['9. Shell plc'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras', 'University'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['instituto de tecnologia para o desenvolvimento-lactec', '2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', 'University'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', 'University'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', 'University'],
#  ['1. Saudi Arabian Oil Co', 'University'],
#  ['8. Chevron Corp'],
#  ['13. PetroChina Co Ltd'],
#  ['8. Chevron Corp'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['instituto tecnológico de aeronáutica - ita', '2. Petrobras'],
#  ['cnpem - centro nacional de pesquisa em energia e materiais',
#   '2. Petrobras'],
#  ['2. Petrobras'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['9. Shell plc', '9. Shell plc'],
#  ['7. Equinor ASA'],
#  ['17. SK', '17. SK'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['17. SK', '17. SK'],
#  ['17. SK', '17. SK'],
#  ['faculdades catolicas', '2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['13. PetroChina Co Ltd'],
#  ['2. Petrobras', 'University'],
#  ['1. Saudi Arabian Oil Co'],
#  ['15. BP p.l.c.'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp', '4. Exxon Mobil Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['8. Chevron Corp'],
#  ['17. SK', '17. SK'],
#  ['2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['17. SK', '17. SK'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp',
#   'University'],
#  ['beijing research institute of chemical industry, china pertroleum & chemical corporation',
#   '10. China Petroleum & Chemical Corp',
#   'University'],
#  ['10. China Petroleum & Chemical Corp',
#   '10. China Petroleum & Chemical Corp'],
#  ['University', '1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['15. BP p.l.c.'],
#  ['1. Saudi Arabian Oil Co'],
#  ['13. PetroChina Co Ltd'],
#  ['17. SK', '17. SK'],
#  ['17. SK', '17. SK'],
#  ['14. Eni S.p.A.'],
#  ['faculdades catolicas', '2. Petrobras'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras', 'University'],
#  ['8. Chevron Corp', 'schlumberger technology corporation'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['14. Eni S.p.A.'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['2. Petrobras'],
#  ['2. Petrobras', 'University'],
#  ['2. Petrobras'],
#  ['1. Saudi Arabian Oil Co', '1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp'],
#  ['1. Saudi Arabian Oil Co'],
#  ['8. Chevron Corp', '8. Chevron Corp', '8. Chevron Corp', '8. Chevron Corp'],
#  ...]

# %%
params0 = np.ones((2,2))
minimum = scipy.optimize.fmin(loss_function, params0, args = (yearmonth,lv_df.values[[3,1]]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Ksunwoo\Desktop\23-2\기예인\dev\tech_pred\top_oil_data.ipynb Cell 55 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y105sZmlsZQ%3D%3D?line=0'>1</a> params0 = np.ones((2,2))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y105sZmlsZQ%3D%3D?line=1'>2</a> minimum = scipy.optimize.fmin(loss_function, params0, args = (yearmonth,lv_df.values[[3,1]]))
#
# NameError: name 'scipy' is not defined

# %%
print(minimum)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Ksunwoo\Desktop\23-2\기예인\dev\tech_pred\top_oil_data.ipynb Cell 56 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> print(minimum)
#
# NameError: name 'minimum' is not defined

# %%
df.columns
# Out:
# Index(['일련번호', '번호', '명칭', '요약', '출원인', '출원인국가', '출원인대표명', '발명자', '발명자국가',
#        '국제특허분류', '공통특허분류', '미국특허분류', '출원번호', '출원일', '공개번호', '공개일', '공고번호',
#        '공고일', '등록번호', '등록일', '우선권번호', '국제출원번호', '국제출원일', '국제공개번호', '국제공개일',
#        'INPADOC 패밀리', 'Simple 패밀리', '심사관', '대리인', '지정국가', '독립 청구항수', '전체 청구항수',
#        '대표 청구항', '대표 청구항(원문)', '권리 현황', '최종 상태', '현재소유자', '권리만료예상일', '자국인용특허',
#        '외국인용특허', '자국피인용특허', '자국인용횟수', '자국피인용횟수', '특허평가등급', '특허평가점수',
#        '발명자평가평균등급', '발명자평가평균점수', 'FI', 'F-Term', 'INPADOC패밀리수',
#        'INPADOC패밀리국가수', 'Simple패밀리수', 'Simple패밀리국가수', '발명자수', 'Genealogy수',
#        '패밀리 번호', '전용실시권자', '통상실시권자', 'INPADOC패밀리국가', 'Simple패밀리국가', '소유권이전여부',
#        '소유권최종양도일', '특허전문 Link', 'companies', '출원일_datetime',
#        'companies_categorized'],
#       dtype='object')

# %%
ipc_df =df.dropna(subset=['국제특허분류'])

# %%
ipc_df['ipc_lst'] = ipc_df['국제특허분류'].apply(lambda x: x.split(','))
# Out:
# C:\Users\Ksunwoo\AppData\Local\Temp\ipykernel_26564\41174437.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ipc_df['ipc_lst'] = ipc_df['국제특허분류'].apply(lambda x: x.split(','))

# %%
ipc_df_exploded = ipc_df.explode('ipc_lst')
ipc_df_exploded_A = ipc_df_exploded[ipc_df_exploded['ipc_lst'].map(lambda x: x.startswith('A'))]
ipc_df_exploded_B = ipc_df_exploded[ipc_df_exploded['ipc_lst'].map(lambda x: x.startswith('B'))]
ipc_df_exploded_C = ipc_df_exploded[ipc_df_exploded['ipc_lst'].map(lambda x: x.startswith('C'))]
ipc_df_exploded_D = ipc_df_exploded[ipc_df_exploded['ipc_lst'].map(lambda x: x.startswith('D'))]
ipc_df_exploded_E = ipc_df_exploded[ipc_df_exploded['ipc_lst'].map(lambda x: x.startswith('E'))]
ipc_df_exploded_F = ipc_df_exploded[ipc_df_exploded['ipc_lst'].map(lambda x: x.startswith('F'))]



print(len(ipc_df_exploded_A))

print(len(ipc_df_exploded_B))

print(len(ipc_df_exploded_C))

print(len(ipc_df_exploded_D))

print(len(ipc_df_exploded_E))

print(len(ipc_df_exploded_F))
# Out:
# 86
# 1759
# 4809
# 27
# 2543
# 625

# %%
ipc_df = df.copy()
ipc_df =ipc_df.dropna(subset=['국제특허분류'])
ipc_df['companies_categorized_unique'] = ipc_df['companies_categorized'].apply(lambda x : list(set(x)))
top_company_list =list(ipc_df['companies_categorized_unique'].value_counts()[:14].index)
ipc_df =ipc_df[ipc_df['companies_categorized_unique'].isin(top_company_list)]
ipc_df['ipc_lst'] = ipc_df['국제특허분류'].apply(lambda x: x.split(','))

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# 그래프 초기화
G = nx.Graph()

# 엣지 추가 (특허 카테고리 기준)
for index, row in ipc_df_network.iterrows():
    companies = row['companies_categorized_unique']
    ipc_categories = row['ipc_lst']
    
    # 모든 회사 쌍에 대해 엣지 추가
    for i in range(len(companies)):
        for j in range(i+1, len(companies)):
            G.add_edge(companies[i], companies[j], ipc=ipc_categories)

# 그래프 그리기
pos = nx.spring_layout(G)  # 레이아웃 설정
plt.figure(figsize=(12, 8))
nx.draw(G, pos, with_labels=True, font_size=8, font_color='black', node_size=100, node_color='skyblue', edge_color='gray')

# 엣지에 특허 카테고리 추가
edge_labels = nx.get_edge_attributes(G, 'ipc')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')

plt.title('특허 참여 회사 네트워크')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Ksunwoo\Desktop\23-2\기예인\dev\tech_pred\top_oil_data.ipynb Cell 62 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y115sZmlsZQ%3D%3D?line=5'>6</a> G = nx.Graph()
#       <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y115sZmlsZQ%3D%3D?line=7'>8</a> # 엣지 추가 (특허 카테고리 기준)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y115sZmlsZQ%3D%3D?line=8'>9</a> for index, row in ipc_df_network.iterrows():
#      <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y115sZmlsZQ%3D%3D?line=9'>10</a>     companies = row['companies_categorized_unique']
#      <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y115sZmlsZQ%3D%3D?line=10'>11</a>     ipc_categories = row['ipc_lst']
#
# NameError: name 'ipc_df_network' is not defined

# %%
ipc_df_network
# Out:
#                                                  ipc_lst  \
# 0      [C09K-008/60,  C09K-008/68,  C09K-008/70,  C09...
# 1      [C07B-041/06,  C07C-045/49,  B01J-023/68,  C07...
# 2              [E21B-041/00,  E21B-049/08,  E21B-043/16]
# 3      [C09K-008/03,  C09K-008/524,  C09K-008/528,  C...
# 4              [C10G-001/10,  C10G-001/00,  C10G-025/00]
# ...                                                  ...
# 13426                                      [F16L-001/26]
# 13427                                      [C07C-027/00]
# 13428                        [C07C-067/00,  C07C-051/16]
# 13429                        [C10G-047/00,  C07C-005/13]
# 13430                                      [C07C-005/27]
#
#       companies_categorized_unique
# 0        [1. Saudi Arabian Oil Co]
# 1                [8. Chevron Corp]
# 2        [1. Saudi Arabian Oil Co]
# 3        [1. Saudi Arabian Oil Co]
# 4                         [17. SK]
# ...                            ...
# 13426            [8. Chevron Corp]
# 13427            [8. Chevron Corp]
# 13428              [15. BP p.l.c.]
# 13429            [8. Chevron Corp]
# 13430            [8. Chevron Corp]
#
# [12358 rows x 2 columns]

# %%
exploded_df = ipc_df_network.explode('ipc_lst').explode('companies_categorized_unique')
exploded_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Ksunwoo\Desktop\23-2\기예인\dev\tech_pred\top_oil_data.ipynb Cell 64 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y120sZmlsZQ%3D%3D?line=0'>1</a> exploded_df = ipc_df_network.explode('ipc_lst').explode('companies_categorized_unique')
#       <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y120sZmlsZQ%3D%3D?line=1'>2</a> exploded_df.head()
#
# NameError: name 'ipc_df_network' is not defined

# %%
exploded_df = ipc_df_network.explode('ipc_lst').explode('companies_categorized_unique')
exploded_df.head()
exploded_df['ipc_code'] = exploded_df['ipc_lst'].apply(lambda x : x.split('-')[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Ksunwoo\Desktop\23-2\기예인\dev\tech_pred\top_oil_data.ipynb Cell 65 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y121sZmlsZQ%3D%3D?line=0'>1</a> exploded_df['ipc_code'] = exploded_df['ipc_lst'].apply(lambda x : x.split('-')[0])
#
# NameError: name 'exploded_df' is not defined

# %%
vector_table = exploded_df.pivot_table(index='companies_categorized_unique', columns='ipc_code', aggfunc='size', fill_value=0)
vector_table = vector_table.div(vector_table.sum(axis=1), axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Ksunwoo\Desktop\23-2\기예인\dev\tech_pred\top_oil_data.ipynb Cell 66 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y122sZmlsZQ%3D%3D?line=0'>1</a> vector_table = exploded_df.pivot_table(index='companies_categorized_unique', columns='ipc_code', aggfunc='size', fill_value=0)
#       <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y122sZmlsZQ%3D%3D?line=1'>2</a> vector_table = vector_table.div(vector_table.sum(axis=1), axis=0)
#
# NameError: name 'exploded_df' is not defined

# %%
from sklearn.metrics.pairwise import cosine_similarity

# 코사인 유사도 계산
similarity_matrix = cosine_similarity(vector_table)

# 결과 데이터프레임 생성
similarity_df = pd.DataFrame(similarity_matrix, index=vector_table.index, columns=vector_table.index)

# 결과 출력

similarity_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Ksunwoo\Desktop\23-2\기예인\dev\tech_pred\top_oil_data.ipynb Cell 67 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y123sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.metrics.pairwise import cosine_similarity
#       <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y123sZmlsZQ%3D%3D?line=2'>3</a> # 코사인 유사도 계산
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y123sZmlsZQ%3D%3D?line=3'>4</a> similarity_matrix = cosine_similarity(vector_table)
#       <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y123sZmlsZQ%3D%3D?line=5'>6</a> # 결과 데이터프레임 생성
#       <a href='vscode-notebook-cell:/c%3A/Users/Ksunwoo/Desktop/23-2/%EA%B8%B0%EC%98%88%EC%9D%B8/dev/tech_pred/top_oil_data.ipynb#Y123sZmlsZQ%3D%3D?line=6'>7</a> similarity_df = pd.DataFrame(similarity_matrix, index=vector_table.index, columns=vector_table.index)
#
# NameError: name 'vector_table' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 히트맵 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(similarity_df, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Cosine Similarity Between Companies')
plt.show()

# %%
ipc_df = df.copy()
ipc_df =ipc_df.dropna(subset=['국제특허분류'])
ipc_df['companies_categorized_unique'] = ipc_df['companies_categorized'].apply(lambda x : list(set(x)))
top_company_list =list(ipc_df['companies_categorized_unique'].value_counts()[:14].index)
ipc_df =ipc_df[ipc_df['companies_categorized_unique'].isin(top_company_list)]
ipc_df['ipc_lst'] = ipc_df['국제특허분류'].apply(lambda x: x.split(','))

# %%
exploded_df= ipc_df.explode('ipc_lst').explode('companies_categorized_unique')
exploded_df
# Out:
#         일련번호            번호                                                 명칭  \
# 0          1  WO23196956A1             FOAM STABILIZATION USING NANOPARTICLES
# 0          1  WO23196956A1             FOAM STABILIZATION USING NANOPARTICLES
# 0          1  WO23196956A1             FOAM STABILIZATION USING NANOPARTICLES
# 0          1  WO23196956A1             FOAM STABILIZATION USING NANOPARTICLES
# 0          1  WO23196956A1             FOAM STABILIZATION USING NANOPARTICLES
# ...      ...           ...                                                ...
# 13428  13465     USRE44206  Oxidation process for the production of carbox...
# 13428  13465     USRE44206  Oxidation process for the production of carbox...
# 13429  13466     US8404912        Process for making high VI lubricating oils
# 13429  13466     US8404912        Process for making high VI lubricating oils
# 13430  13470     US8222473                   Isomerization of light paraffins
#
#                                                       요약  \
# 0      A method of stimulating a hydrocarbon-bearing ...
# 0      A method of stimulating a hydrocarbon-bearing ...
# 0      A method of stimulating a hydrocarbon-bearing ...
# 0      A method of stimulating a hydrocarbon-bearing ...
# 0      A method of stimulating a hydrocarbon-bearing ...
# ...                                                  ...
# 13428  An oxidation process for the production of alk...
# 13428  An oxidation process for the production of alk...
# 13429  A process for making a high VI lubricating bas...
# 13429  A process for making a high VI lubricating bas...
# 13430  A process for isomerizing light paraffins usin...
#
#                                                      출원인  출원인국가  \
# 0      saudi arabian oil company|aramco services company  SA|US
# 0      saudi arabian oil company|aramco services company  SA|US
# 0      saudi arabian oil company|aramco services company  SA|US
# 0      saudi arabian oil company|aramco services company  SA|US
# 0      saudi arabian oil company|aramco services company  SA|US
# ...                                                  ...    ...
# 13428                               bp chemicals limited     GB
# 13428                               bp chemicals limited     GB
# 13429                                chevron u.s.a. inc.     US
# 13429                                chevron u.s.a. inc.     US
# 13430                                chevron u.s.a. inc.     US
#
#                  출원인대표명                                                발명자  \
# 0                   NaN  KARADKAR, Prasad, Baburao|HARBI, Bader, G.|BAT...
# 0                   NaN  KARADKAR, Prasad, Baburao|HARBI, Bader, G.|BAT...
# 0                   NaN  KARADKAR, Prasad, Baburao|HARBI, Bader, G.|BAT...
# 0                   NaN  KARADKAR, Prasad, Baburao|HARBI, Bader, G.|BAT...
# 0                   NaN  KARADKAR, Prasad, Baburao|HARBI, Bader, G.|BAT...
# ...                 ...                                                ...
# 13428  BP CHEMICALS LTD  Ferguson; Ewen James|Lucy; Andrew Richard|Robe...
# 13428  BP CHEMICALS LTD  Ferguson; Ewen James|Lucy; Andrew Richard|Robe...
# 13429   CHEVRON USA INC                             Miller; Stephen Joseph
# 13429   CHEVRON USA INC                             Miller; Stephen Joseph
# 13430   CHEVRON USA INC  Chen; Cong-Yan|Ouyang; Xiaoying|Davis; Tracy M...
#
#                 발명자국가                                             국제특허분류  ...  \
# 0            SA|SA|SA  C09K-008/60, C09K-008/68, C09K-008/70, C09K-00...  ...
# 0            SA|SA|SA  C09K-008/60, C09K-008/68, C09K-008/70, C09K-00...  ...
# 0            SA|SA|SA  C09K-008/60, C09K-008/68, C09K-008/70, C09K-00...  ...
# 0            SA|SA|SA  C09K-008/60, C09K-008/68, C09K-008/70, C09K-00...  ...
# 0            SA|SA|SA  C09K-008/60, C09K-008/68, C09K-008/70, C09K-00...  ...
# ...               ...                                                ...  ...
# 13428  GB|GB|GB|GB|GB                           C07C-067/00, C07C-051/16  ...
# 13428  GB|GB|GB|GB|GB                           C07C-067/00, C07C-051/16  ...
# 13429              US                           C10G-047/00, C07C-005/13  ...
# 13429              US                           C10G-047/00, C07C-005/13  ...
# 13430     US|US|US|US                                        C07C-005/27  ...
#
#                                           INPADOC패밀리국가  \
# 0                                                  NaN
# 0                                                  NaN
# 0                                                  NaN
# 0                                                  NaN
# 0                                                  NaN
# ...                                                ...
# 13428  AT,BR,CN,EP,ES,GB,JP,KR,MY,NO,RS,RU,TW,UA,US,WO
# 13428  AT,BR,CN,EP,ES,GB,JP,KR,MY,NO,RS,RU,TW,UA,US,WO
# 13429                       CA,CN,EP,IN,JP,KR,SG,US,WO
# 13429                       CA,CN,EP,IN,JP,KR,SG,US,WO
# 13430                                            US,WO
#
#                                            Simple패밀리국가 소유권이전여부 소유권최종양도일  \
# 0                                                  NaN     NaN      NaN
# 0                                                  NaN     NaN      NaN
# 0                                                  NaN     NaN      NaN
# 0                                                  NaN     NaN      NaN
# 0                                                  NaN     NaN      NaN
# ...                                                ...     ...      ...
# 13428  AT,BR,CN,EP,ES,GB,JP,KR,MY,NO,RS,RU,TW,UA,US,WO       N      NaN
# 13428  AT,BR,CN,EP,ES,GB,JP,KR,MY,NO,RS,RU,TW,UA,US,WO       N      NaN
# 13429                       CA,CN,EP,IN,JP,KR,SG,US,WO       N      NaN
# 13429                       CA,CN,EP,IN,JP,KR,SG,US,WO       N      NaN
# 13430                                            US,WO       N      NaN
#
#                                                특허전문 Link  \
# 0      https://service.wisdomain.net/FullTextService/...
# 0      https://service.wisdomain.net/FullTextService/...
# 0      https://service.wisdomain.net/FullTextService/...
# 0      https://service.wisdomain.net/FullTextService/...
# 0      https://service.wisdomain.net/FullTextService/...
# ...                                                  ...
# 13428  https://service.wisdomain.net/FullTextService/...
# 13428  https://service.wisdomain.net/FullTextService/...
# 13429  https://service.wisdomain.net/FullTextService/...
# 13429  https://service.wisdomain.net/FullTextService/...
# 13430  https://service.wisdomain.net/FullTextService/...
#
#                                                companies  출원일_datetime  \
# 0      [aramco services company, saudi arabian oil co...    2023-04-07
# 0      [aramco services company, saudi arabian oil co...    2023-04-07
# 0      [aramco services company, saudi arabian oil co...    2023-04-07
# 0      [aramco services company, saudi arabian oil co...    2023-04-07
# 0      [aramco services company, saudi arabian oil co...    2023-04-07
# ...                                                  ...           ...
# 13428                             [bp chemicals limited]    2011-05-16
# 13428                             [bp chemicals limited]    2011-05-16
# 13429                              [chevron u.s.a. inc.]    2012-05-09
# 13429                              [chevron u.s.a. inc.]    2012-05-09
# 13430                              [chevron u.s.a. inc.]    2011-12-22
#
#                                    companies_categorized  \
# 0      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...
# 0      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...
# 0      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...
# 0      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...
# 0      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...
# ...                                                  ...
# 13428                                    [15. BP p.l.c.]
# 13428                                    [15. BP p.l.c.]
# 13429                                  [8. Chevron Corp]
# 13429                                  [8. Chevron Corp]
# 13430                                  [8. Chevron Corp]
#
#       companies_categorized_unique       ipc_lst
# 0          1. Saudi Arabian Oil Co   C09K-008/60
# 0          1. Saudi Arabian Oil Co   C09K-008/68
# 0          1. Saudi Arabian Oil Co   C09K-008/70
# 0          1. Saudi Arabian Oil Co   C09K-008/86
# 0          1. Saudi Arabian Oil Co   C09K-008/94
# ...                            ...           ...
# 13428                15. BP p.l.c.   C07C-067/00
# 13428                15. BP p.l.c.   C07C-051/16
# 13429              8. Chevron Corp   C10G-047/00
# 13429              8. Chevron Corp   C07C-005/13
# 13430              8. Chevron Corp   C07C-005/27
#
# [55536 rows x 68 columns]

# %%
# exploded_df=ipc_df.explode('ipc_lst')
vector_table = exploded_df.pivot_table(index='companies_categorized_unique', columns='ipc_lst', aggfunc='size', fill_value=0)
vector_table = vector_table.div(vector_table.sum(axis=1), axis=0)

from sklearn.metrics.pairwise import cosine_similarity

# 코사인 유사도 계산
similarity_matrix = cosine_similarity(vector_table)

# 결과 데이터프레임 생성
similarity_df = pd.DataFrame(similarity_matrix, index=vector_table.index, columns=vector_table.index)

# 결과 출력

import seaborn as sns
import matplotlib.pyplot as plt

# 히트맵 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(similarity_df, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Cosine Similarity Between Companies')
plt.show()

# %%
ipc_df
# Out:
#         일련번호            번호                                                 명칭  \
# 0          1  WO23196956A1             FOAM STABILIZATION USING NANOPARTICLES
# 1          2  WO23196806A1  CHROMIUM-CATALYZED REACTIONS OF CARBON MONOXID...
# 2          3  WO23196613A1  METHOD FOR CO2 SEQUESTRATION MEASUREMENT AND Q...
# 3          4  WO23195875A1                 RADIATION ACTIVATED WELL TREATMENT
# 4          5  WO23195710A1  METHOD AND DEVICE FOR PRODUCING WASTE PLASTIC ...
# ...      ...           ...                                                ...
# 13426  13463     US8517634  Systems and methods for replacing, repositioni...
# 13427  13464     US8487010       Converting carbon oxides in gas phase fluids
# 13428  13465     USRE44206  Oxidation process for the production of carbox...
# 13429  13466     US8404912        Process for making high VI lubricating oils
# 13430  13470     US8222473                   Isomerization of light paraffins
#
#                                                       요약  \
# 0      A method of stimulating a hydrocarbon-bearing ...
# 1      A hydrocarbon compound and carbon monoxide are...
# 2      A process for quantifying CO2 sequestration wi...
# 3      A well treatment composition may include a cap...
# 4      The present disclosure provides a method for p...
# ...                                                  ...
# 13426  Methods and systems are provided for replacing...
# 13427  A process for reducing the carbon oxide conten...
# 13428  An oxidation process for the production of alk...
# 13429  A process for making a high VI lubricating bas...
# 13430  A process for isomerizing light paraffins usin...
#
#                                                      출원인  출원인국가  \
# 0      saudi arabian oil company|aramco services company  SA|US
# 1                   chevron phillips chemical company lp     US
# 2      saudi arabian oil company|aramco services company  SA|US
# 3       saudi arabian oil company|aramco innovations llc  SA|RU
# 4       sk innovation co., ltd.|sk geo centric co., ltd.  KR|KR
# ...                                                  ...    ...
# 13426                                chevron u.s.a. inc.     US
# 13427                                chevron u.s.a. inc.     US
# 13428                               bp chemicals limited     GB
# 13429                                chevron u.s.a. inc.     US
# 13430                                chevron u.s.a. inc.     US
#
#                  출원인대표명                                                발명자  \
# 0                   NaN  KARADKAR, Prasad, Baburao|HARBI, Bader, G.|BAT...
# 1                   NaN  MCDANIEL, Max, P.|REFVIK, Mitchell, D.|PRAETOR...
# 2                   NaN               AL-QASIM, Abdulaziz, S.|KOKAL, Sunil
# 3                   NaN            ZHARNIKOV, Timur|ORLOV, Maxim|CHEN, Tao
# 4                   NaN  JO, Sanghwan|KANG, Sookil|LEE, Howon|JUNG, Jae...
# ...                 ...                                                ...
# 13426   CHEVRON USA INC      Liso; Stephen|Harding; Eric|O'Donnell; Thomas
# 13427   CHEVRON USA INC  Thomas; David|Travis; Rod|Moppert; Michael|Kal...
# 13428  BP CHEMICALS LTD  Ferguson; Ewen James|Lucy; Andrew Richard|Robe...
# 13429   CHEVRON USA INC                             Miller; Stephen Joseph
# 13430   CHEVRON USA INC  Chen; Cong-Yan|Ouyang; Xiaoying|Davis; Tracy M...
#
#                       발명자국가  \
# 0                  SA|SA|SA
# 1      US|US|US|US|US|US|US
# 2                     SA|SA
# 3                  RU|RU|SA
# 4         KR|KR|KR|KR|KR|KR
# ...                     ...
# 13426              US|US|US
# 13427     US|US|US|US|US|US
# 13428        GB|GB|GB|GB|GB
# 13429                    US
# 13430           US|US|US|US
#
#                                                   국제특허분류  ...  \
# 0      C09K-008/60, C09K-008/68, C09K-008/70, C09K-00...  ...
# 1      C07B-041/06, C07C-045/49, B01J-023/68, C07C-02...  ...
# 2                  E21B-041/00, E21B-049/08, E21B-043/16  ...
# 3      C09K-008/03, C09K-008/524, C09K-008/528, C09K-...  ...
# 4                  C10G-001/10, C10G-001/00, C10G-025/00  ...
# ...                                                  ...  ...
# 13426                                        F16L-001/26  ...
# 13427                                        C07C-027/00  ...
# 13428                           C07C-067/00, C07C-051/16  ...
# 13429                           C10G-047/00, C07C-005/13  ...
# 13430                                        C07C-005/27  ...
#
#                                           INPADOC패밀리국가  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 13426                                AU,BR,GB,NO,US,WO
# 13427                                   AU,CA,EP,US,WO
# 13428  AT,BR,CN,EP,ES,GB,JP,KR,MY,NO,RS,RU,TW,UA,US,WO
# 13429                       CA,CN,EP,IN,JP,KR,SG,US,WO
# 13430                                            US,WO
#
#                                            Simple패밀리국가 소유권이전여부 소유권최종양도일  \
# 0                                                  NaN     NaN      NaN
# 1                                                  NaN     NaN      NaN
# 2                                                  NaN     NaN      NaN
# 3                                                  NaN     NaN      NaN
# 4                                                  NaN     NaN      NaN
# ...                                                ...     ...      ...
# 13426                                AU,BR,GB,NO,US,WO       N      NaN
# 13427                                   AU,CA,EP,US,WO       N      NaN
# 13428  AT,BR,CN,EP,ES,GB,JP,KR,MY,NO,RS,RU,TW,UA,US,WO       N      NaN
# 13429                       CA,CN,EP,IN,JP,KR,SG,US,WO       N      NaN
# 13430                                            US,WO       N      NaN
#
#                                                특허전문 Link  \
# 0      https://service.wisdomain.net/FullTextService/...
# 1      https://service.wisdomain.net/FullTextService/...
# 2      https://service.wisdomain.net/FullTextService/...
# 3      https://service.wisdomain.net/FullTextService/...
# 4      https://service.wisdomain.net/FullTextService/...
# ...                                                  ...
# 13426  https://service.wisdomain.net/FullTextService/...
# 13427  https://service.wisdomain.net/FullTextService/...
# 13428  https://service.wisdomain.net/FullTextService/...
# 13429  https://service.wisdomain.net/FullTextService/...
# 13430  https://service.wisdomain.net/FullTextService/...
#
#                                                companies  출원일_datetime  \
# 0      [aramco services company, saudi arabian oil co...    2023-04-07
# 1                 [chevron phillips chemical company lp]    2023-04-04
# 2      [aramco services company, saudi arabian oil co...    2023-04-07
# 3      [aramco innovations llc, saudi arabian oil com...    2022-04-08
# 4      [sk geo centric co., ltd., sk innovation co., ...    2023-04-03
# ...                                                  ...           ...
# 13426                              [chevron u.s.a. inc.]    2011-03-30
# 13427                              [chevron u.s.a. inc.]    2012-06-27
# 13428                             [bp chemicals limited]    2011-05-16
# 13429                              [chevron u.s.a. inc.]    2012-05-09
# 13430                              [chevron u.s.a. inc.]    2011-12-22
#
#                                    companies_categorized  \
# 0      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...
# 1                                      [8. Chevron Corp]
# 2      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...
# 3      [1. Saudi Arabian Oil Co, 1. Saudi Arabian Oil...
# 4                                       [17. SK, 17. SK]
# ...                                                  ...
# 13426                                  [8. Chevron Corp]
# 13427                                  [8. Chevron Corp]
# 13428                                    [15. BP p.l.c.]
# 13429                                  [8. Chevron Corp]
# 13430                                  [8. Chevron Corp]
#
#       companies_categorized_unique  \
# 0        [1. Saudi Arabian Oil Co]
# 1                [8. Chevron Corp]
# 2        [1. Saudi Arabian Oil Co]
# 3        [1. Saudi Arabian Oil Co]
# 4                         [17. SK]
# ...                            ...
# 13426            [8. Chevron Corp]
# 13427            [8. Chevron Corp]
# 13428              [15. BP p.l.c.]
# 13429            [8. Chevron Corp]
# 13430            [8. Chevron Corp]
#
#                                                  ipc_lst
# 0      [C09K-008/60,  C09K-008/68,  C09K-008/70,  C09...
# 1      [C07B-041/06,  C07C-045/49,  B01J-023/68,  C07...
# 2              [E21B-041/00,  E21B-049/08,  E21B-043/16]
# 3      [C09K-008/03,  C09K-008/524,  C09K-008/528,  C...
# 4              [C10G-001/10,  C10G-001/00,  C10G-025/00]
# ...                                                  ...
# 13426                                      [F16L-001/26]
# 13427                                      [C07C-027/00]
# 13428                        [C07C-067/00,  C07C-051/16]
# 13429                        [C10G-047/00,  C07C-005/13]
# 13430                                      [C07C-005/27]
#
# [12358 rows x 68 columns]

# %%
import pandas as pd

df = pd.read_excel('Top_oil_companies.xlsx')
df.dropna(subset=['출원인'], inplace=True)
df['출원인'] = df['출원인'].str.lower()

df.head()
# Out:
#    일련번호            번호                                                 명칭  \
# 0     1  WO23196956A1             FOAM STABILIZATION USING NANOPARTICLES
# 1     2  WO23196806A1  CHROMIUM-CATALYZED REACTIONS OF CARBON MONOXID...
# 2     3  WO23196613A1  METHOD FOR CO2 SEQUESTRATION MEASUREMENT AND Q...
# 3     4  WO23195875A1                 RADIATION ACTIVATED WELL TREATMENT
# 4     5  WO23195710A1  METHOD AND DEVICE FOR PRODUCING WASTE PLASTIC ...
#
#                                                   요약  \
# 0  A method of stimulating a hydrocarbon-bearing ...
# 1  A hydrocarbon compound and carbon monoxide are...
# 2  A process for quantifying CO2 sequestration wi...
# 3  A well treatment composition may include a cap...
# 4  The present disclosure provides a method for p...
#
#                                                  출원인  출원인국가 출원인대표명  \
# 0  saudi arabian oil company|aramco services company  SA|US    NaN
# 1               chevron phillips chemical company lp     US    NaN
# 2  saudi arabian oil company|aramco services company  SA|US    NaN
# 3   saudi arabian oil company|aramco innovations llc  SA|RU    NaN
# 4   sk innovation co., ltd.|sk geo centric co., ltd.  KR|KR    NaN
#
#                                                  발명자                 발명자국가  \
# 0  KARADKAR, Prasad, Baburao|HARBI, Bader, G.|BAT...              SA|SA|SA
# 1  MCDANIEL, Max, P.|REFVIK, Mitchell, D.|PRAETOR...  US|US|US|US|US|US|US
# 2               AL-QASIM, Abdulaziz, S.|KOKAL, Sunil                 SA|SA
# 3            ZHARNIKOV, Timur|ORLOV, Maxim|CHEN, Tao              RU|RU|SA
# 4  JO, Sanghwan|KANG, Sookil|LEE, Howon|JUNG, Jae...     KR|KR|KR|KR|KR|KR
#
#                                               국제특허분류  ... 발명자수 Genealogy수  \
# 0  C09K-008/60, C09K-008/68, C09K-008/70, C09K-00...  ...    3        NaN
# 1  C07B-041/06, C07C-045/49, B01J-023/68, C07C-02...  ...    7        NaN
# 2              E21B-041/00, E21B-049/08, E21B-043/16  ...    2        NaN
# 3  C09K-008/03, C09K-008/524, C09K-008/528, C09K-...  ...    3        NaN
# 4              C10G-001/10, C10G-001/00, C10G-025/00  ...    6        NaN
#
#   패밀리 번호 전용실시권자 통상실시권자 INPADOC패밀리국가  Simple패밀리국가  소유권이전여부 소유권최종양도일  \
# 0    NaN    NaN    NaN          NaN          NaN      NaN      NaN
# 1    NaN    NaN    NaN          NaN          NaN      NaN      NaN
# 2    NaN    NaN    NaN          NaN          NaN      NaN      NaN
# 3    NaN    NaN    NaN          NaN          NaN      NaN      NaN
# 4    NaN    NaN    NaN          NaN          NaN      NaN      NaN
#
#                                            특허전문 Link
# 0  https://service.wisdomain.net/FullTextService/...
# 1  https://service.wisdomain.net/FullTextService/...
# 2  https://service.wisdomain.net/FullTextService/...
# 3  https://service.wisdomain.net/FullTextService/...
# 4  https://service.wisdomain.net/FullTextService/...
#
# [5 rows x 63 columns]

# %%
df['companies'] = df['출원인'].apply(lambda x: list(sorted(set(x.split('|')))))

yes_on_filtered = ['sk on co, ltd.' in lst  or 'sk on co., ltd' in lst or 'sk on co., ltd.' in lst   for lst in df['companies']]
no_on_filtered = [not boolean for boolean in yes_on_filtered]
no_on_df = df.loc[no_on_filtered]
no_on_df
# Out:
#         일련번호            번호                                                 명칭  \
# 0          1  WO23196956A1             FOAM STABILIZATION USING NANOPARTICLES
# 1          2  WO23196806A1  CHROMIUM-CATALYZED REACTIONS OF CARBON MONOXID...
# 2          3  WO23196613A1  METHOD FOR CO2 SEQUESTRATION MEASUREMENT AND Q...
# 3          4  WO23195875A1                 RADIATION ACTIVATED WELL TREATMENT
# 4          5  WO23195710A1  METHOD AND DEVICE FOR PRODUCING WASTE PLASTIC ...
# ...      ...           ...                                                ...
# 13426  13463     US8517634  Systems and methods for replacing, repositioni...
# 13427  13464     US8487010       Converting carbon oxides in gas phase fluids
# 13428  13465     USRE44206  Oxidation process for the production of carbox...
# 13429  13466     US8404912        Process for making high VI lubricating oils
# 13430  13470     US8222473                   Isomerization of light paraffins
#
#                                                       요약  \
# 0      A method of stimulating a hydrocarbon-bearing ...
# 1      A hydrocarbon compound and carbon monoxide are...
# 2      A process for quantifying CO2 sequestration wi...
# 3      A well treatment composition may include a cap...
# 4      The present disclosure provides a method for p...
# ...                                                  ...
# 13426  Methods and systems are provided for replacing...
# 13427  A process for reducing the carbon oxide conten...
# 13428  An oxidation process for the production of alk...
# 13429  A process for making a high VI lubricating bas...
# 13430  A process for isomerizing light paraffins usin...
#
#                                                      출원인  출원인국가  \
# 0      saudi arabian oil company|aramco services company  SA|US
# 1                   chevron phillips chemical company lp     US
# 2      saudi arabian oil company|aramco services company  SA|US
# 3       saudi arabian oil company|aramco innovations llc  SA|RU
# 4       sk innovation co., ltd.|sk geo centric co., ltd.  KR|KR
# ...                                                  ...    ...
# 13426                                chevron u.s.a. inc.     US
# 13427                                chevron u.s.a. inc.     US
# 13428                               bp chemicals limited     GB
# 13429                                chevron u.s.a. inc.     US
# 13430                                chevron u.s.a. inc.     US
#
#                  출원인대표명                                                발명자  \
# 0                   NaN  KARADKAR, Prasad, Baburao|HARBI, Bader, G.|BAT...
# 1                   NaN  MCDANIEL, Max, P.|REFVIK, Mitchell, D.|PRAETOR...
# 2                   NaN               AL-QASIM, Abdulaziz, S.|KOKAL, Sunil
# 3                   NaN            ZHARNIKOV, Timur|ORLOV, Maxim|CHEN, Tao
# 4                   NaN  JO, Sanghwan|KANG, Sookil|LEE, Howon|JUNG, Jae...
# ...                 ...                                                ...
# 13426   CHEVRON USA INC      Liso; Stephen|Harding; Eric|O'Donnell; Thomas
# 13427   CHEVRON USA INC  Thomas; David|Travis; Rod|Moppert; Michael|Kal...
# 13428  BP CHEMICALS LTD  Ferguson; Ewen James|Lucy; Andrew Richard|Robe...
# 13429   CHEVRON USA INC                             Miller; Stephen Joseph
# 13430   CHEVRON USA INC  Chen; Cong-Yan|Ouyang; Xiaoying|Davis; Tracy M...
#
#                       발명자국가  \
# 0                  SA|SA|SA
# 1      US|US|US|US|US|US|US
# 2                     SA|SA
# 3                  RU|RU|SA
# 4         KR|KR|KR|KR|KR|KR
# ...                     ...
# 13426              US|US|US
# 13427     US|US|US|US|US|US
# 13428        GB|GB|GB|GB|GB
# 13429                    US
# 13430           US|US|US|US
#
#                                                   국제특허분류  ... Genealogy수  \
# 0      C09K-008/60, C09K-008/68, C09K-008/70, C09K-00...  ...        NaN
# 1      C07B-041/06, C07C-045/49, B01J-023/68, C07C-02...  ...        NaN
# 2                  E21B-041/00, E21B-049/08, E21B-043/16  ...        NaN
# 3      C09K-008/03, C09K-008/524, C09K-008/528, C09K-...  ...        NaN
# 4                  C10G-001/10, C10G-001/00, C10G-025/00  ...        NaN
# ...                                                  ...  ...        ...
# 13426                                        F16L-001/26  ...        0.0
# 13427                                        C07C-027/00  ...        0.0
# 13428                           C07C-067/00, C07C-051/16  ...        1.0
# 13429                           C10G-047/00, C07C-005/13  ...        0.0
# 13430                                        C07C-005/27  ...        0.0
#
#            패밀리 번호 전용실시권자 통상실시권자  \
# 0             NaN    NaN    NaN
# 1             NaN    NaN    NaN
# 2             NaN    NaN    NaN
# 3             NaN    NaN    NaN
# 4             NaN    NaN    NaN
# ...           ...    ...    ...
# 13426  46932219.0    NaN    NaN
# 13427  48741569.0    NaN    NaN
# 13428   9959404.0    NaN    NaN
# 13429  47892289.0    NaN    NaN
# 13430  46465461.0    NaN    NaN
#
#                                           INPADOC패밀리국가  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 13426                                AU,BR,GB,NO,US,WO
# 13427                                   AU,CA,EP,US,WO
# 13428  AT,BR,CN,EP,ES,GB,JP,KR,MY,NO,RS,RU,TW,UA,US,WO
# 13429                       CA,CN,EP,IN,JP,KR,SG,US,WO
# 13430                                            US,WO
#
#                                            Simple패밀리국가  소유권이전여부  소유권최종양도일  \
# 0                                                  NaN      NaN       NaN
# 1                                                  NaN      NaN       NaN
# 2                                                  NaN      NaN       NaN
# 3                                                  NaN      NaN       NaN
# 4                                                  NaN      NaN       NaN
# ...                                                ...      ...       ...
# 13426                                AU,BR,GB,NO,US,WO        N       NaN
# 13427                                   AU,CA,EP,US,WO        N       NaN
# 13428  AT,BR,CN,EP,ES,GB,JP,KR,MY,NO,RS,RU,TW,UA,US,WO        N       NaN
# 13429                       CA,CN,EP,IN,JP,KR,SG,US,WO        N       NaN
# 13430                                            US,WO        N       NaN
#
#                                                특허전문 Link  \
# 0      https://service.wisdomain.net/FullTextService/...
# 1      https://service.wisdomain.net/FullTextService/...
# 2      https://service.wisdomain.net/FullTextService/...
# 3      https://service.wisdomain.net/FullTextService/...
# 4      https://service.wisdomain.net/FullTextService/...
# ...                                                  ...
# 13426  https://service.wisdomain.net/FullTextService/...
# 13427  https://service.wisdomain.net/FullTextService/...
# 13428  https://service.wisdomain.net/FullTextService/...
# 13429  https://service.wisdomain.net/FullTextService/...
# 13430  https://service.wisdomain.net/FullTextService/...
#
#                                                companies
# 0      [aramco services company, saudi arabian oil co...
# 1                 [chevron phillips chemical company lp]
# 2      [aramco services company, saudi arabian oil co...
# 3      [aramco innovations llc, saudi arabian oil com...
# 4      [sk geo centric co., ltd., sk innovation co., ...
# ...                                                  ...
# 13426                              [chevron u.s.a. inc.]
# 13427                              [chevron u.s.a. inc.]
# 13428                             [bp chemicals limited]
# 13429                              [chevron u.s.a. inc.]
# 13430                              [chevron u.s.a. inc.]
#
# [13232 rows x 64 columns]

# %%
########################sk on 지운 버전 ##################
########################sk on 지운 버전 ##################
########################sk on 지운 버전 ##################
########################sk on 지운 버전 ##################
import seaborn as sns
import matplotlib.pyplot as plt

def categorize_company(names, companies_variations):
    result = []
    for name in names:
        category_assigned = False
        for category, variations in companies_variations.items():
            if any(name.lower() in variation.lower() for variation in variations):
                if category == "Miscellaneous":
                    result.append(name)
                else:
                    result.append(category)
                category_assigned = True
                break
        if not category_assigned:
            result.append(name)
    return result


latest_file_path = 'rules_assigning_companies.txt'
data = []
with open(latest_file_path, 'r', encoding='utf-8') as file:
    current_category = ""
    for line in file:
        if line.endswith(":\n"):
            current_category = line[:-2]
        elif line.strip():
            data.append([current_category, line.strip()])

rules = pd.DataFrame(data, columns=["Category", "Name"])
rules_dict = rules.groupby('Category')['Name'].apply(list).to_dict()
print(rules_dict["17. SK"])
print(rules_dict.items())
print(rules_dict.keys())


no_on_df['companies'] = no_on_df['출원인'].apply(lambda x: list(sorted(set(x.split('|')))))
no_on_df['companies'] = no_on_df['companies'].apply(lambda x: categorize_company(x, rules_dict))
no_on_df['companies'] = no_on_df['companies'].apply(lambda x: list(set(x)))

category_counts = no_on_df['companies'].explode().value_counts()
print(category_counts[:30])


# # Visualization
# plt.figure(figsize=(12, 8))
# sns.barplot(x=category_counts[:15].values, y=category_counts[:15].index, palette="muted")
# plt.title("Number of Entries per Category")
# plt.xlabel("Number of Entries")
# plt.ylabel("Category")
# plt.show()

from sklearn.metrics.pairwise import cosine_similarity


# 회사명 통일성 확보
# df['companies'] = df['출원인'].apply(lambda x: list(sorted(set(x.split('|')))))

# Create separate rows for each combination
df_expanded = no_on_df.explode('companies')
# 결과 출력
print(df_expanded['companies'].value_counts()[:30])

df_expanded=df_expanded.dropna(subset=['국제특허분류'])
df_expanded['ipc_code'] = df_expanded['국제특허분류'].apply(lambda x: x.split(','))
df_explode =df_expanded.explode(['ipc_code'])
df_explode['ipc_code']
df_explode['ipc_code_front'] = df_explode['ipc_code'].apply(lambda x : x.split('-')[0]).apply(lambda x : x.strip())

vector_table = df_explode.pivot_table(index='companies', columns='ipc_code_front', aggfunc='size', fill_value=0)
vector_table = vector_table.div(vector_table.sum(axis=1), axis=0)

top12_connected_company = df_expanded['companies'].value_counts()[:12].index
top12_sk_vector_table = vector_table.loc[list(top12_connected_company)]
top12_sk_similarity_matrix = cosine_similarity(top12_sk_vector_table)



# 코사인 유사도 계산
similarity_matrix = cosine_similarity(vector_table)

# 결과 데이터프레임 생성
similarity_df = pd.DataFrame(similarity_matrix, index=vector_table.index, columns=vector_table.index)


# 결과 데이터프레임 생성
top10_sk_similarity_df = pd.DataFrame(top12_sk_similarity_matrix, index=top12_sk_vector_table.index, columns=top12_sk_vector_table.index)


# 히트맵 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(top10_sk_similarity_df, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.1)
plt.xticks([])

plt.title('Cosine Similarity Between Companies without SK-ON')
plt.show()
# Out:
# ['sabic sk nexlene company pte. ltd.', 'sk earthon co., ltd.', 'sk energy co ltd', 'sk energy co., ltd.', 'sk enmove co., ltd', 'sk gc americas inc.', 'sk geo centric co., ltd.', 'sk global chemical co ltd', 'sk global chemical co, ltd.', 'sk global chemical co., ltd.', 'sk gloval chemical co., ltd.', 'sk ie technology co ltd', 'sk ie technology co. , ltd.', 'sk ie technology co., ltd.', 'sk inc.', 'sk incheon petrochem co., ltd.', 'sk innovation  co., ltd.', 'sk innovation co ltd', 'sk innovation co, ltd', 'sk innovation co, ltd.', 'sk innovation co. ltd.', 'sk innovation co., lt.d', 'sk innovation co., ltd', 'sk innovation co., ltd.', 'sk innovation co.,ltd', 'sk innovation co.,ltd.', 'sk innovations co., ltd.', 'sk lubricants co., ltd.', 'sk on co, ltd.', 'sk on co., ltd', 'sk on co., ltd.', 'sk-materials co., ltd.', 'skgc americas inc.']
# dict_items([('1. Saudi Arabian Oil Co', ['aramco far east (beijing) business service co. ltd (abs)', 'aramco far east (beijing) business service co. ltd.', 'aramco far east (beijing) business services co., ltd.', 'aramco innovations llc', 'aramco overseas company b.v.', 'aramco overseas company uk ltd', 'aramco overseas company uk ltd.', 'aramco service comapny', 'aramco services company', 'aramco sevices company', 'king fahd university of petroleum & minerals, saudi arabian oil company', 'saidi arabian oil company', 'saud arabian oil company', 'saudi  arabian oil company', 'saudi arabia oil company', 'saudi arabian company', 'saudi arabian oil co', 'saudi arabian oil comapny', 'saudi arabian oil comoanv', 'saudi arabian oil comoany', 'saudi arabian oil company', 'saudi arabian oil company and', 'saudi arabian oil company, dhahran, saudi arabia', 'saudi arabian oil companyd', 'saudi arabian oil compay', 'saudi arabian oil compnay', 'saudi arabian oil componv', 'saudi arabian oil conpany', 'saudi arabian oli company', 'saudi arabian upstream technology company', 'saudi aramco technologies company', 'saudi arbian oil company', 'saudia arabian oil company', 'suadi arabian oil company']), ('10. China Petroleum & Chemical Corp', ['beiging research institute of chemical industry, china petroleum & chemical corporation', 'beijing reaearch institute of chemical industry, china petroleum & chemical corporation', 'beijing reasearch institute of chemical industry, china petroleum & chemical corporation', 'beijing research inst of chemical industry china petroleum & chemical corp', 'beijing research institute of chemical industry', 'beijing research institute of chemical industry china petroleum & chemical corporation', 'beijing research institute of chemical industry, china petroleum & chemical coporation', 'beijing research institute of chemical industry, china petroleum & chemical corp', 'beijing research institute of chemical industry, china petroleum & chemical corp.', 'beijing research institute of chemical industry, china petroleum & chemical corporatin', 'beijing research institute of chemical industry, china petroleum & chemical corporation', 'beijing research institute of chemical industry, china petroleum & chimical corporation', 'beijing research institute of chemical industry, china petroleum & chrmical corporation', 'beijing research institute of chemical industry, china petroleum and chemical corporation', 'beijing research institute of chemical industry, china petrolium & chemical corporation', 'china petrolum & chemical corporation', 'china petroleum & chamical corporation', 'china petroleum & cheimcal corporation', 'china petroleum & chemcial corporation', 'china petroleum & chemical  corporation', 'china petroleum & chemical corp', 'china petroleum & chemical corp.', 'china petroleum & chemical corporation', 'china petroleum & chemical corporation and beijing research institute of chemical industry', 'china petroleum & chemical corporation beijing research institute of chemical industry', 'china petroleum & chemical corporation beijing research institute of chemical industry, china petroleum & chemical corporation', 'china petroleum & chemical corporation exploration & production research institute', 'china petroleum & chemical corporation ltd', 'china petroleum & chemical corporation ltd gas storage branch', 'china petroleum & chemical corporation ltd.', 'china petroleum & chemical corporation qingdao research institute of safety engineering', 'china petroleum & chemical corporation southwest oil & gas company', 'china petroleum chemical corporation', 'china research institute of petroleum processing, sinopec', 'dalian research institute of petroleum and petrochemicals, sinopec corp.', 'drilling engineering echnology research institute of sinopec zhongyuan petroleum engineering co., lt', 'drilling engineering technology research inst. of sinopec zhongyuan petroleum engineering co., ltd', 'drilling engineering technolog ...
# dict_keys(['1. Saudi Arabian Oil Co', '10. China Petroleum & Chemical Corp', '13. PetroChina Co Ltd', '14. Eni S.p.A.', '15. BP p.l.c.', '16. Suncor Energy Inc', '17. SK', '2. Petrobras', '3. PJSC LUKOIL', '4. Exxon Mobil Corp', '6. TotalEnergies SE', '7. Equinor ASA', '8. Chevron Corp', '9. Shell plc', 'Miscellaneous', 'Senai', 'University'])
# C:\Users\Ksunwoo\AppData\Local\Temp\ipykernel_26564\1476035309.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_on_df['companies'] = no_on_df['출원인'].apply(lambda x: list(sorted(set(x.split('|')))))
# C:\Users\Ksunwoo\AppData\Local\Temp\ipykernel_26564\1476035309.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_on_df['companies'] = no_on_df['companies'].apply(lambda x: categorize_company(x, rules_dict))
# C:\Users\Ksunwoo\AppData\Local\Temp\ipykernel_26564\1476035309.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_on_df['companies'] = no_on_df['companies'].apply(lambda x: list(set(x)))
# companies
# 1. Saudi Arabian Oil Co                                              4725
# 8. Chevron Corp                                                      2275
# 9. Shell plc                                                         1939
# 17. SK                                                               1046
# 10. China Petroleum & Chemical Corp                                   732
# 15. BP p.l.c.                                                         665
# University                                                            499
# 2. Petrobras                                                          376
# 14. Eni S.p.A.                                                        361
# 6. TotalEnergies SE                                                   341
# 13. PetroChina Co Ltd                                                 292
# 7. Equinor ASA                                                        235
# 16. Suncor Energy Inc                                                  88
# 4. Exxon Mobil Corp                                                    56
# schlumberger technology corporation                                    33
# ifp energies nouvelles                                                 27
# halliburton energy services, inc.                                      21
# uop llc                                                                19
# jgc catalysts and chemicals ltd.                                       18
# triad national security, llc                                           16
# Senai                                                                  15
# centre national de la recherche scientifique                           13
# japan cooperation center petroleum                                     13
# sabic global technologies b.v.                                         11
# georgia tech research corporation                                      10
# versalis s.p.a.                                                        10
# shanghai advanced research institute, chinese academy of sciences       8
# dalian institute of chemical physics, chinese academy of sciences       8
# wireless instrumentation systems as                                     8
# marathon oil canada corporation                                         7
# Name: count, dtype: int64
# companies
# 1. Saudi Arabian Oil Co                                              4725
# 8. Chevron Corp                                                      2275
# 9. Shell plc                                                         1939
# 17. SK                                                               1046
# 10. China Petroleum & Chemical Corp                                   732
# 15. BP p.l.c.                                                         665
# University                                                            499
# 2. Petrobras                                                          376
# 14. Eni S.p.A.                                                        361
# 6. TotalEnergies SE                                                   341
# 13. PetroChina Co Ltd                                                 292
# 7. Equinor ASA                                                        235
# 16. Suncor Energy Inc                                                  88
# 4. Exxon Mobil Corp                                                    56
# schlumberger technology corporation                                    33
# ifp energies nouvelles                                                 27
# halliburton energy services, inc.                                      21
# uop llc                                                                19
# jgc catalysts and chemicals ltd.                                       18
# triad national security, llc                                           16
# Senai                                                                  15
# centre national de la recherche scientifique                           13
# japan cooperation center petroleum                                     13
# sabic global technologies b.v.                                         11
# georgia tech research corporation                                      10
# versalis s.p.a.                                                        10
# shanghai advanced research institute, chinese academy of sciences       8
# dalian institute of chemical physics, chinese academy of sciences       8
# wireless instrumentation systems as                                     8
# marathon oil canada corporation                                         7
# Name: count, dtype: int64

# %%
df['companies'] = df['출원인'].apply(lambda x: list(sorted(set(x.split('|')))))

yes_on_filtered = ['sk on co, ltd.' in lst  or 'sk on co., ltd' in lst or 'sk on co., ltd.' in lst   for lst in df['companies']]
no_on_filtered = [not boolean for boolean in yes_on_filtered]
no_on_df = df.loc[no_on_filtered]

########################sk on 지운 버전 ##################
########################sk on 지운 버전 ##################
########################sk on 지운 버전 ##################
########################sk on 지운 버전 ##################
import seaborn as sns
import matplotlib.pyplot as plt

def categorize_company(names, companies_variations):
    result = []
    for name in names:
        category_assigned = False
        for category, variations in companies_variations.items():
            if any(name.lower() in variation.lower() for variation in variations):
                if category == "Miscellaneous":
                    result.append(name)
                else:
                    result.append(category)
                category_assigned = True
                break
        if not category_assigned:
            result.append(name)
    return result


latest_file_path = 'rules_assigning_companies.txt'
data = []
with open(latest_file_path, 'r', encoding='utf-8') as file:
    current_category = ""
    for line in file:
        if line.endswith(":\n"):
            current_category = line[:-2]
        elif line.strip():
            data.append([current_category, line.strip()])

rules = pd.DataFrame(data, columns=["Category", "Name"])
rules_dict = rules.groupby('Category')['Name'].apply(list).to_dict()
print(rules_dict["17. SK"])
print(rules_dict.items())
print(rules_dict.keys())


no_on_df['companies'] = no_on_df['출원인'].apply(lambda x: list(sorted(set(x.split('|')))))
no_on_df['companies'] = no_on_df['companies'].apply(lambda x: categorize_company(x, rules_dict))
no_on_df['companies'] = no_on_df['companies'].apply(lambda x: list(set(x)))

category_counts = no_on_df['companies'].explode().value_counts()
print(category_counts[:30])


# # Visualization
# plt.figure(figsize=(12, 8))
# sns.barplot(x=category_counts[:15].values, y=category_counts[:15].index, palette="muted")
# plt.title("Number of Entries per Category")
# plt.xlabel("Number of Entries")
# plt.ylabel("Category")
# plt.show()

from sklearn.metrics.pairwise import cosine_similarity


# 회사명 통일성 확보
# df['companies'] = df['출원인'].apply(lambda x: list(sorted(set(x.split('|')))))

# Create separate rows for each combination
df_expanded = no_on_df.explode('companies')
# 결과 출력
print(df_expanded['companies'].value_counts()[:30])

df_expanded=df_expanded.dropna(subset=['국제특허분류'])
df_expanded['ipc_code'] = df_expanded['국제특허분류'].apply(lambda x: x.split(','))
df_explode =df_expanded.explode(['ipc_code'])
df_explode['ipc_code']
df_explode['ipc_code_front'] = df_explode['ipc_code'].apply(lambda x : x.split('-')[0]).apply(lambda x : x.strip())

vector_table = df_explode.pivot_table(index='companies', columns='ipc_code_front', aggfunc='size', fill_value=0)
vector_table = vector_table.div(vector_table.sum(axis=1), axis=0)

top12_connected_company = df_expanded['companies'].value_counts()[:12].index
top12_sk_vector_table = vector_table.loc[list(top12_connected_company)]
top12_sk_similarity_matrix = cosine_similarity(top12_sk_vector_table)



# 코사인 유사도 계산
similarity_matrix = cosine_similarity(vector_table)

# 결과 데이터프레임 생성
similarity_df = pd.DataFrame(similarity_matrix, index=vector_table.index, columns=vector_table.index)


# 결과 데이터프레임 생성
top10_sk_similarity_df = pd.DataFrame(top12_sk_similarity_matrix, index=top12_sk_vector_table.index, columns=top12_sk_vector_table.index)


# 히트맵 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(top10_sk_similarity_df, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.1)
plt.xticks([])

plt.title('Cosine Similarity Between Companies without SK-ON')
plt.show()

# %%
########################sk on 안 지운 버전 ##################
########################sk on 안 지운 버전 ##################
########################sk on 안 지운 버전 ##################
########################sk on 안 지운 버전 ##################
import seaborn as sns
import matplotlib.pyplot as plt

def categorize_company(names, companies_variations):
    result = []
    for name in names:
        category_assigned = False
        for category, variations in companies_variations.items():
            if any(name.lower() in variation.lower() for variation in variations):
                if category == "Miscellaneous":
                    result.append(name)
                else:
                    result.append(category)
                category_assigned = True
                break
        if not category_assigned:
            result.append(name)
    return result


latest_file_path = 'rules_assigning_companies.txt'
data = []
with open(latest_file_path, 'r', encoding='utf-8') as file:
    current_category = ""
    for line in file:
        if line.endswith(":\n"):
            current_category = line[:-2]
        elif line.strip():
            data.append([current_category, line.strip()])

rules = pd.DataFrame(data, columns=["Category", "Name"])
rules_dict = rules.groupby('Category')['Name'].apply(list).to_dict()
print(rules_dict["17. SK"])
print(rules_dict.items())
print(rules_dict.keys())


df['companies'] = df['출원인'].apply(lambda x: list(sorted(set(x.split('|')))))
df['companies'] = df['companies'].apply(lambda x: categorize_company(x, rules_dict))
df['companies'] = df['companies'].apply(lambda x: list(set(x)))

category_counts = df['companies'].explode().value_counts()
print(category_counts[:30])


# # Visualization
# plt.figure(figsize=(12, 8))
# sns.barplot(x=category_counts[:15].values, y=category_counts[:15].index, palette="muted")
# plt.title("Number of Entries per Category")
# plt.xlabel("Number of Entries")
# plt.ylabel("Category")
# plt.show()

from sklearn.metrics.pairwise import cosine_similarity


# 회사명 통일성 확보
# df['companies'] = df['출원인'].apply(lambda x: list(sorted(set(x.split('|')))))

# Create separate rows for each combination
df_expanded = df.explode('companies')
# 결과 출력
print(df_expanded['companies'].value_counts()[:30])

df_expanded=df_expanded.dropna(subset=['국제특허분류'])
df_expanded['ipc_code'] = df_expanded['국제특허분류'].apply(lambda x: x.split(','))
df_explode =df_expanded.explode(['ipc_code'])
df_explode['ipc_code']
df_explode['ipc_code_front'] = df_explode['ipc_code'].apply(lambda x : x.split('-')[0]).apply(lambda x : x.strip())

vector_table = df_explode.pivot_table(index='companies', columns='ipc_code_front', aggfunc='size', fill_value=0)
vector_table = vector_table.div(vector_table.sum(axis=1), axis=0)

top12_connected_company = df_expanded['companies'].value_counts()[:12].index
top12_sk_vector_table = vector_table.loc[list(top12_connected_company)]
top12_sk_similarity_matrix = cosine_similarity(top12_sk_vector_table)



# 코사인 유사도 계산
similarity_matrix = cosine_similarity(vector_table)

# 결과 데이터프레임 생성
similarity_df = pd.DataFrame(similarity_matrix, index=vector_table.index, columns=vector_table.index)


# 결과 데이터프레임 생성
top10_sk_similarity_df = pd.DataFrame(top12_sk_similarity_matrix, index=top12_sk_vector_table.index, columns=top12_sk_vector_table.index)


# 히트맵 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(top10_sk_similarity_df, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.1)
plt.xticks([])

plt.title('Cosine Similarity Between Companies')
plt.show()
# Out:
# ['sabic sk nexlene company pte. ltd.', 'sk earthon co., ltd.', 'sk energy co ltd', 'sk energy co., ltd.', 'sk enmove co., ltd', 'sk gc americas inc.', 'sk geo centric co., ltd.', 'sk global chemical co ltd', 'sk global chemical co, ltd.', 'sk global chemical co., ltd.', 'sk gloval chemical co., ltd.', 'sk ie technology co ltd', 'sk ie technology co. , ltd.', 'sk ie technology co., ltd.', 'sk inc.', 'sk incheon petrochem co., ltd.', 'sk innovation  co., ltd.', 'sk innovation co ltd', 'sk innovation co, ltd', 'sk innovation co, ltd.', 'sk innovation co. ltd.', 'sk innovation co., lt.d', 'sk innovation co., ltd', 'sk innovation co., ltd.', 'sk innovation co.,ltd', 'sk innovation co.,ltd.', 'sk innovations co., ltd.', 'sk lubricants co., ltd.', 'sk on co, ltd.', 'sk on co., ltd', 'sk on co., ltd.', 'sk-materials co., ltd.', 'skgc americas inc.']
# dict_items([('1. Saudi Arabian Oil Co', ['aramco far east (beijing) business service co. ltd (abs)', 'aramco far east (beijing) business service co. ltd.', 'aramco far east (beijing) business services co., ltd.', 'aramco innovations llc', 'aramco overseas company b.v.', 'aramco overseas company uk ltd', 'aramco overseas company uk ltd.', 'aramco service comapny', 'aramco services company', 'aramco sevices company', 'king fahd university of petroleum & minerals, saudi arabian oil company', 'saidi arabian oil company', 'saud arabian oil company', 'saudi  arabian oil company', 'saudi arabia oil company', 'saudi arabian company', 'saudi arabian oil co', 'saudi arabian oil comapny', 'saudi arabian oil comoanv', 'saudi arabian oil comoany', 'saudi arabian oil company', 'saudi arabian oil company and', 'saudi arabian oil company, dhahran, saudi arabia', 'saudi arabian oil companyd', 'saudi arabian oil compay', 'saudi arabian oil compnay', 'saudi arabian oil componv', 'saudi arabian oil conpany', 'saudi arabian oli company', 'saudi arabian upstream technology company', 'saudi aramco technologies company', 'saudi arbian oil company', 'saudia arabian oil company', 'suadi arabian oil company']), ('10. China Petroleum & Chemical Corp', ['beiging research institute of chemical industry, china petroleum & chemical corporation', 'beijing reaearch institute of chemical industry, china petroleum & chemical corporation', 'beijing reasearch institute of chemical industry, china petroleum & chemical corporation', 'beijing research inst of chemical industry china petroleum & chemical corp', 'beijing research institute of chemical industry', 'beijing research institute of chemical industry china petroleum & chemical corporation', 'beijing research institute of chemical industry, china petroleum & chemical coporation', 'beijing research institute of chemical industry, china petroleum & chemical corp', 'beijing research institute of chemical industry, china petroleum & chemical corp.', 'beijing research institute of chemical industry, china petroleum & chemical corporatin', 'beijing research institute of chemical industry, china petroleum & chemical corporation', 'beijing research institute of chemical industry, china petroleum & chimical corporation', 'beijing research institute of chemical industry, china petroleum & chrmical corporation', 'beijing research institute of chemical industry, china petroleum and chemical corporation', 'beijing research institute of chemical industry, china petrolium & chemical corporation', 'china petrolum & chemical corporation', 'china petroleum & chamical corporation', 'china petroleum & cheimcal corporation', 'china petroleum & chemcial corporation', 'china petroleum & chemical  corporation', 'china petroleum & chemical corp', 'china petroleum & chemical corp.', 'china petroleum & chemical corporation', 'china petroleum & chemical corporation and beijing research institute of chemical industry', 'china petroleum & chemical corporation beijing research institute of chemical industry', 'china petroleum & chemical corporation beijing research institute of chemical industry, china petroleum & chemical corporation', 'china petroleum & chemical corporation exploration & production research institute', 'china petroleum & chemical corporation ltd', 'china petroleum & chemical corporation ltd gas storage branch', 'china petroleum & chemical corporation ltd.', 'china petroleum & chemical corporation qingdao research institute of safety engineering', 'china petroleum & chemical corporation southwest oil & gas company', 'china petroleum chemical corporation', 'china research institute of petroleum processing, sinopec', 'dalian research institute of petroleum and petrochemicals, sinopec corp.', 'drilling engineering echnology research institute of sinopec zhongyuan petroleum engineering co., lt', 'drilling engineering technology research inst. of sinopec zhongyuan petroleum engineering co., ltd', 'drilling engineering technolog ...
# dict_keys(['1. Saudi Arabian Oil Co', '10. China Petroleum & Chemical Corp', '13. PetroChina Co Ltd', '14. Eni S.p.A.', '15. BP p.l.c.', '16. Suncor Energy Inc', '17. SK', '2. Petrobras', '3. PJSC LUKOIL', '4. Exxon Mobil Corp', '6. TotalEnergies SE', '7. Equinor ASA', '8. Chevron Corp', '9. Shell plc', 'Miscellaneous', 'Senai', 'University'])
# companies
# 1. Saudi Arabian Oil Co                                              4725
# 8. Chevron Corp                                                      2275
# 9. Shell plc                                                         1939
# 17. SK                                                               1122
# 10. China Petroleum & Chemical Corp                                   732
# 15. BP p.l.c.                                                         665
# University                                                            499
# 2. Petrobras                                                          376
# 14. Eni S.p.A.                                                        361
# 6. TotalEnergies SE                                                   341
# 13. PetroChina Co Ltd                                                 292
# 7. Equinor ASA                                                        235
# 16. Suncor Energy Inc                                                  88
# 4. Exxon Mobil Corp                                                    56
# schlumberger technology corporation                                    33
# ifp energies nouvelles                                                 27
# halliburton energy services, inc.                                      21
# uop llc                                                                19
# jgc catalysts and chemicals ltd.                                       18
# triad national security, llc                                           16
# Senai                                                                  15
# centre national de la recherche scientifique                           13
# japan cooperation center petroleum                                     13
# sabic global technologies b.v.                                         11
# georgia tech research corporation                                      10
# versalis s.p.a.                                                        10
# shanghai advanced research institute, chinese academy of sciences       8
# dalian institute of chemical physics, chinese academy of sciences       8
# wireless instrumentation systems as                                     8
# marathon oil canada corporation                                         7
# Name: count, dtype: int64
# companies
# 1. Saudi Arabian Oil Co                                              4725
# 8. Chevron Corp                                                      2275
# 9. Shell plc                                                         1939
# 17. SK                                                               1122
# 10. China Petroleum & Chemical Corp                                   732
# 15. BP p.l.c.                                                         665
# University                                                            499
# 2. Petrobras                                                          376
# 14. Eni S.p.A.                                                        361
# 6. TotalEnergies SE                                                   341
# 13. PetroChina Co Ltd                                                 292
# 7. Equinor ASA                                                        235
# 16. Suncor Energy Inc                                                  88
# 4. Exxon Mobil Corp                                                    56
# schlumberger technology corporation                                    33
# ifp energies nouvelles                                                 27
# halliburton energy services, inc.                                      21
# uop llc                                                                19
# jgc catalysts and chemicals ltd.                                       18
# triad national security, llc                                           16
# Senai                                                                  15
# centre national de la recherche scientifique                           13
# japan cooperation center petroleum                                     13
# sabic global technologies b.v.                                         11
# georgia tech research corporation                                      10
# versalis s.p.a.                                                        10
# shanghai advanced research institute, chinese academy of sciences       8
# dalian institute of chemical physics, chinese academy of sciences       8
# wireless instrumentation systems as                                     8
# marathon oil canada corporation                                         7
# Name: count, dtype: int64
